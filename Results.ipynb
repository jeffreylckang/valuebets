# %% [markdown]
# ## Model Comparison using RSME

# %%
import pandas as pd

# %%
# Define the table data with all values cleared
data_RMSE = {
    "Model Type": [
        "Single Sport NN Binary", 
        "Single Sport NN Binary", 
        "Single Sport NN Continuous", 
        "Single Sport NN Continuous",
        "Multi-Sport NCF Binary", 
        "Multi-Sport NCF Binary", 
        "Multi-Sport NCF Continuous", 
        "Multi-Sport NCF Continuous",
        "Multi-Sport NCF Continuous Dual loss", 
        "Multi-Sport NCF Continuous Dual loss", 
        "Multi-Sport NCF Binary w/ Sport Specific Layers", 
        "Multi-Sport NCF Binary w/ Sport Specific Layers", 
        "Multi-Sport NCF Continuous w/ Sport Specific Layers",
        "Multi-Sport NCF Continuous w/ Sport Specific Layers",
        "Random Forest Binary", 
        "Random Forest Binary",
        "Random Forest Continuous",
        "Random Forest Continuous",
        "Baseline",
        "Baseline"
    ],
    "Data Source": [
        "All sports", "Basketball only", 
        "All sports", "Basketball only", 
        "All sports", "Basketball only",
        "All sports", "Basketball only",
        "All sports", "Basketball only",
        "All sports", "Basketball only",
        "All sports", "Basketball only",
        "All sports", "Basketball only",
        "All sports", "Basketball only",
        "All sports", "Basketball only",
    ],
    "Proportion of Home Value Bets Overall": [""] * 20,
    "Proportion of Away Value Bets Overall": [""] * 20,
    "Mean Correct Home Value Bet": [""] * 20,
    "Mean Correct Away Value Bet": [""] * 20,
    "Mean Home Payout Diff (Value Bet - Actual)": [""] * 20,
    "Mean Away Payout Diff (Value Bet - Actual)": [""] * 20,
    "Mean Home VB Payout Diff (Value Bet - Non Value Bet)": [""] * 20,
    "Mean Away VB Payout Diff (Value Bet - Non Value Bet)": [""] * 20,
    "Home Value Bet ROI (%)": [""] * 20,
    "Away Value Bet ROI (%)": [""] * 20,
    "Home Non Value Bet ROI (%)": [""] * 20,
    "Away Non Value Bet ROI (%)": [""] * 20,
    "Home Actual ROI (%)": [""] * 20,
    "Away Actual ROI (%)": [""] * 20,
    "Per Home Value Bets, the Average Home Adjusted Payout": [""] * 20,
    "Per Away Value Bets, the Average Away Adjusted Payout": [""] * 20,
    "Per Home Non-Value Bets, the Average Home Adjusted Payout": [""] * 20,
    "Per Away Non-Value Bets, the Average Away Adjusted Payout": [""] * 20,
    "Theoretical Average EV for Home Value Bets": [""] * 20,
    "Theoretical Average EV for All Home Bets": [""] * 20,
    "Theoretical Average EV for Home Non-Value Bets": [""] * 20,
    "Theoretical Average EV for Away Value Bets": [""] * 20,
    "Theoretical Average EV for All Away Bets": [""] * 20,
    "Theoretical Average EV for Away Non-Value Bets": [""] * 20,
    "Home Accuracy (Threshold 0.5)": [""] * 20,
    "Away Accuracy (Threshold 0.5)": [""] * 20,
    "Home Brier Score": [""] * 20,
    "Away Brier Score": [""] * 20,
    "Home F1 Score": [""] * 20,
    "Away F1 Score": [""] * 20
}

# Convert to DataFrame
comparison_RMSE = pd.DataFrame(data_RMSE)

# NN Binary
comparison_RMSE.loc[0, "Proportion of Home Value Bets Overall"] = 0.5499
comparison_RMSE.loc[0, "Proportion of Away Value Bets Overall"] = 0.4331
comparison_RMSE.loc[0, "Mean Correct Home Value Bet"] = 0.5499
comparison_RMSE.loc[0, "Mean Correct Away Value Bet"] = 0.4331
comparison_RMSE.loc[0, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.1610
comparison_RMSE.loc[0, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.0172
comparison_RMSE.loc[0, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.1517
comparison_RMSE.loc[0, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 9.7929
comparison_RMSE.loc[0, "Home Value Bet ROI (%)"] = -30.64
comparison_RMSE.loc[0, "Away Value Bet ROI (%)"] = 26.50
comparison_RMSE.loc[0, "Home Non Value Bet ROI (%)"] = -196.42
comparison_RMSE.loc[0, "Away Non Value Bet ROI (%)"] = -199.70
comparison_RMSE.loc[0, "Home Actual ROI (%)"] = -105.26
comparison_RMSE.loc[0, "Away Actual ROI (%)"] = -101.73
comparison_RMSE.loc[0, "Per Home Value Bets, the Average Home Adjusted Payout"] = 6.9363
comparison_RMSE.loc[0, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.6504
comparison_RMSE.loc[0, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -282.5176
comparison_RMSE.loc[0, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -3395.8244
comparison_RMSE.loc[0, "Theoretical Average EV for Home Value Bets"] = 6.8833
comparison_RMSE.loc[0, "Theoretical Average EV for All Home Bets"] = -0.5540
comparison_RMSE.loc[0, "Theoretical Average EV for Home Non-Value Bets"] = -9.6390
comparison_RMSE.loc[0, "Theoretical Average EV for Away Value Bets"] = 12.6320
comparison_RMSE.loc[0, "Theoretical Average EV for All Away Bets"] = -0.1692
comparison_RMSE.loc[0, "Theoretical Average EV for Away Non-Value Bets"] = -9.9494
comparison_RMSE.loc[0, "Home Accuracy (Threshold 0.5)"] = 0.9997
comparison_RMSE.loc[0, "Away Accuracy (Threshold 0.5)"] = 0.9997
comparison_RMSE.loc[0, "Home Brier Score"] = 0.0002
comparison_RMSE.loc[0, "Away Brier Score"] = 0.0002
comparison_RMSE.loc[0, "Home F1 Score"] = 0.9998
comparison_RMSE.loc[0, "Away F1 Score"] = 0.9997

comparison_RMSE.loc[1, "Proportion of Home Value Bets Overall"] = 0.5696
comparison_RMSE.loc[1, "Proportion of Away Value Bets Overall"] = 0.4274
comparison_RMSE.loc[1, "Mean Correct Home Value Bet"] = 0.5696
comparison_RMSE.loc[1, "Mean Correct Away Value Bet"] = 0.4260
comparison_RMSE.loc[1, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.0496
comparison_RMSE.loc[1, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.0172
comparison_RMSE.loc[1, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.7947
comparison_RMSE.loc[1, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 9.6813
comparison_RMSE.loc[1, "Home Value Bet ROI (%)"] = -27.17
comparison_RMSE.loc[1, "Away Value Bet ROI (%)"] = 26.93
comparison_RMSE.loc[1, "Home Non Value Bet ROI (%)"] = -198.85
comparison_RMSE.loc[1, "Away Non Value Bet ROI (%)"] = -199.70
comparison_RMSE.loc[1, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[1, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[1, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.2833
comparison_RMSE.loc[1, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.7348
comparison_RMSE.loc[1, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -1188.9458
comparison_RMSE.loc[1, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -6382.0779
comparison_RMSE.loc[1, "Theoretical Average EV for Home Value Bets"] = 7.2599
comparison_RMSE.loc[1, "Theoretical Average EV for All Home Bets"] = -0.1144
comparison_RMSE.loc[1, "Theoretical Average EV for Home Non-Value Bets"] = -9.8740
comparison_RMSE.loc[1, "Theoretical Average EV for Away Value Bets"] = 12.6905
comparison_RMSE.loc[1, "Theoretical Average EV for All Away Bets"] = -0.2812
comparison_RMSE.loc[1, "Theoretical Average EV for Away Non-Value Bets"] = -9.9625
comparison_RMSE.loc[1, "Home Accuracy (Threshold 0.5)"] = 0.9979
comparison_RMSE.loc[1, "Away Accuracy (Threshold 0.5)"] = 0.9979
comparison_RMSE.loc[1, "Home Brier Score"] = 0.0014
comparison_RMSE.loc[1, "Away Brier Score"] = 0.0014
comparison_RMSE.loc[1, "Home F1 Score"] = 0.9981
comparison_RMSE.loc[1, "Away F1 Score"] = 0.9975

# NN Continuous
comparison_RMSE.loc[2, "Proportion of Home Value Bets Overall"] = 0.2165
comparison_RMSE.loc[2, "Proportion of Away Value Bets Overall"] = 0.2342
comparison_RMSE.loc[2, "Mean Correct Home Value Bet"] = 0.0775
comparison_RMSE.loc[2, "Mean Correct Away Value Bet"] = 0.0694
comparison_RMSE.loc[2, "Mean Home Payout Diff (Value Bet - Actual)"] = -7.3329
comparison_RMSE.loc[2, "Mean Away Payout Diff (Value Bet - Actual)"] = -7.1213
comparison_RMSE.loc[2, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -5.1921
comparison_RMSE.loc[2, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -4.4154
comparison_RMSE.loc[2, "Home Value Bet ROI (%)"] = -101.11
comparison_RMSE.loc[2, "Away Value Bet ROI (%)"] = -84.44
comparison_RMSE.loc[2, "Home Non Value Bet ROI (%)"] = -106.41
comparison_RMSE.loc[2, "Away Non Value Bet ROI (%)"] = -107.01
comparison_RMSE.loc[2, "Home Actual ROI (%)"] = -105.26
comparison_RMSE.loc[2, "Away Actual ROI (%)"] = -101.73
comparison_RMSE.loc[2, "Per Home Value Bets, the Average Home Adjusted Payout"] = -0.3108
comparison_RMSE.loc[2, "Per Away Value Bets, the Average Away Adjusted Payout"] = 5.2511
comparison_RMSE.loc[2, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -1.0295
comparison_RMSE.loc[2, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -1.4701
comparison_RMSE.loc[2, "Theoretical Average EV for Home Value Bets"] = 1.4901
comparison_RMSE.loc[2, "Theoretical Average EV for All Home Bets"] = -0.1017
comparison_RMSE.loc[2, "Theoretical Average EV for Home Non-Value Bets"] = -0.5416
comparison_RMSE.loc[2, "Theoretical Average EV for Away Value Bets"] = 1.1830
comparison_RMSE.loc[2, "Theoretical Average EV for All Away Bets"] = -0.2313
comparison_RMSE.loc[2, "Theoretical Average EV for Away Non-Value Bets"] = -0.6637
comparison_RMSE.loc[2, "Home Accuracy (Threshold 0.5)"] = 0.6773
comparison_RMSE.loc[2, "Away Accuracy (Threshold 0.5)"] = 0.6773
comparison_RMSE.loc[2, "Home Brier Score"] = 0.2058
comparison_RMSE.loc[2, "Away Brier Score"] = 0.2058
comparison_RMSE.loc[2, "Home F1 Score"] = 0.7333
comparison_RMSE.loc[2, "Away F1 Score"] = 0.5913

comparison_RMSE.loc[3, "Proportion of Home Value Bets Overall"] = 0.1858
comparison_RMSE.loc[3, "Proportion of Away Value Bets Overall"] = 0.1096
comparison_RMSE.loc[3, "Mean Correct Home Value Bet"] = 0.0782
comparison_RMSE.loc[3, "Mean Correct Away Value Bet"] = 0.0437
comparison_RMSE.loc[3, "Mean Home Payout Diff (Value Bet - Actual)"] = -7.9903
comparison_RMSE.loc[3, "Mean Away Payout Diff (Value Bet - Actual)"] = -8.4930
comparison_RMSE.loc[3, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -6.0866
comparison_RMSE.loc[3, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -7.2703
comparison_RMSE.loc[3, "Home Value Bet ROI (%)"] = -97.54
comparison_RMSE.loc[3, "Away Value Bet ROI (%)"] = -88.43
comparison_RMSE.loc[3, "Home Non Value Bet ROI (%)"] = -101.87
comparison_RMSE.loc[3, "Away Non Value Bet ROI (%)"] = -104.62
comparison_RMSE.loc[3, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[3, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[3, "Per Home Value Bets, the Average Home Adjusted Payout"] = 0.5856
comparison_RMSE.loc[3, "Per Away Value Bets, the Average Away Adjusted Payout"] = 2.9002
comparison_RMSE.loc[3, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -0.3068
comparison_RMSE.loc[3, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -1.0733
comparison_RMSE.loc[3, "Theoretical Average EV for Home Value Bets"] = 1.2685
comparison_RMSE.loc[3, "Theoretical Average EV for All Home Bets"] = -0.1506
comparison_RMSE.loc[3, "Theoretical Average EV for Home Non-Value Bets"] = -0.4745
comparison_RMSE.loc[3, "Theoretical Average EV for Away Value Bets"] = 1.0268
comparison_RMSE.loc[3, "Theoretical Average EV for All Away Bets"] = -0.5626
comparison_RMSE.loc[3, "Theoretical Average EV for Away Non-Value Bets"] = -0.7582
comparison_RMSE.loc[3, "Home Accuracy (Threshold 0.5)"] = 0.6514
comparison_RMSE.loc[3, "Away Accuracy (Threshold 0.5)"] = 0.6514
comparison_RMSE.loc[3, "Home Brier Score"] = 0.2224
comparison_RMSE.loc[3, "Away Brier Score"] = 0.2224
comparison_RMSE.loc[3, "Home F1 Score"] = 0.7163
comparison_RMSE.loc[3, "Away F1 Score"] = 0.5480

# NCF Binary
comparison_RMSE.loc[4, "Proportion of Home Value Bets Overall"] = 0.4977
comparison_RMSE.loc[4, "Proportion of Away Value Bets Overall"] = 0.4294
comparison_RMSE.loc[4, "Mean Correct Home Value Bet"] = 0.3257
comparison_RMSE.loc[4, "Mean Correct Away Value Bet"] = 0.2393
comparison_RMSE.loc[4, "Mean Home Payout Diff (Value Bet - Actual)"] = -4.1477
comparison_RMSE.loc[4, "Mean Away Payout Diff (Value Bet - Actual)"] = -3.4136
comparison_RMSE.loc[4, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 1.8364
comparison_RMSE.loc[4, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 3.3765
comparison_RMSE.loc[4, "Home Value Bet ROI (%)"] = -79.76
comparison_RMSE.loc[4, "Away Value Bet ROI (%)"] = -41.86
comparison_RMSE.loc[4, "Home Non Value Bet ROI (%)"] = -117.43
comparison_RMSE.loc[4, "Away Non Value Bet ROI (%)"] = -140.18
comparison_RMSE.loc[4, "Home Actual ROI (%)"] = -98.68
comparison_RMSE.loc[4, "Away Actual ROI (%)"] = -97.96
comparison_RMSE.loc[4, "Per Home Value Bets, the Average Home Adjusted Payout"] = 3.0921
comparison_RMSE.loc[4, "Per Away Value Bets, the Average Away Adjusted Payout"] = 10.4331
comparison_RMSE.loc[4, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -3.6185
comparison_RMSE.loc[4, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -11.8770
comparison_RMSE.loc[4, "Theoretical Average EV for Home Value Bets"] = 7.6839
comparison_RMSE.loc[4, "Theoretical Average EV for All Home Bets"] = 1.3290
comparison_RMSE.loc[4, "Theoretical Average EV for Home Non-Value Bets"] = -4.9673
comparison_RMSE.loc[4, "Theoretical Average EV for Away Value Bets"] = 10.4692
comparison_RMSE.loc[4, "Theoretical Average EV for All Away Bets"] = 1.0609
comparison_RMSE.loc[4, "Theoretical Average EV for Away Non-Value Bets"] = -6.0181
comparison_RMSE.loc[4, "Home Accuracy (Threshold 0.5)"] = 0.6870
comparison_RMSE.loc[4, "Away Accuracy (Threshold 0.5)"] = 0.6870
comparison_RMSE.loc[4, "Home Brier Score"] = 0.2195
comparison_RMSE.loc[4, "Away Brier Score"] = 0.2195
comparison_RMSE.loc[4, "Home F1 Score"] = 0.7319
comparison_RMSE.loc[4, "Away F1 Score"] = 0.6242

comparison_RMSE.loc[5, "Proportion of Home Value Bets Overall"] = 0.4890
comparison_RMSE.loc[5, "Proportion of Away Value Bets Overall"] = 0.4132
comparison_RMSE.loc[5, "Mean Correct Home Value Bet"] = 0.2881
comparison_RMSE.loc[5, "Mean Correct Away Value Bet"] = 0.2151
comparison_RMSE.loc[5, "Mean Home Payout Diff (Value Bet - Actual)"] = -5.4081
comparison_RMSE.loc[5, "Mean Away Payout Diff (Value Bet - Actual)"] = -3.2639
comparison_RMSE.loc[5, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -0.9223
comparison_RMSE.loc[5, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 3.1878
comparison_RMSE.loc[5, "Home Value Bet ROI (%)"] = -108.26
comparison_RMSE.loc[5, "Away Value Bet ROI (%)"] = -43.85
comparison_RMSE.loc[5, "Home Non Value Bet ROI (%)"] = -94.17
comparison_RMSE.loc[5, "Away Non Value Bet ROI (%)"] = -144.38
comparison_RMSE.loc[5, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[5, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[5, "Per Home Value Bets, the Average Home Adjusted Payout"] = -1.4024
comparison_RMSE.loc[5, "Per Away Value Bets, the Average Away Adjusted Payout"] = 10.7863
comparison_RMSE.loc[5, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 1.0453
comparison_RMSE.loc[5, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -12.2972
comparison_RMSE.loc[5, "Theoretical Average EV for Home Value Bets"] = 6.6472
comparison_RMSE.loc[5, "Theoretical Average EV for All Home Bets"] = 0.4282
comparison_RMSE.loc[5, "Theoretical Average EV for Home Non-Value Bets"] = -5.5228
comparison_RMSE.loc[5, "Theoretical Average EV for Away Value Bets"] = 10.3120
comparison_RMSE.loc[5, "Theoretical Average EV for All Away Bets"] = 1.3344
comparison_RMSE.loc[5, "Theoretical Average EV for Away Non-Value Bets"] = -4.9866
comparison_RMSE.loc[5, "Home Accuracy (Threshold 0.5)"] = 0.6529
comparison_RMSE.loc[5, "Away Accuracy (Threshold 0.5)"] = 0.6529
comparison_RMSE.loc[5, "Home Brier Score"] = 0.2592
comparison_RMSE.loc[5, "Away Brier Score"] = 0.2592
comparison_RMSE.loc[5, "Home F1 Score"] = 0.7102
comparison_RMSE.loc[5, "Away F1 Score"] = 0.5672

# NCF Continuous
comparison_RMSE.loc[6, "Proportion of Home Value Bets Overall"] = 0.4397
comparison_RMSE.loc[6, "Proportion of Away Value Bets Overall"] = 0.6075
comparison_RMSE.loc[6, "Mean Correct Home Value Bet"] = 0.1911
comparison_RMSE.loc[6, "Mean Correct Away Value Bet"] = 0.2037
comparison_RMSE.loc[6, "Mean Home Payout Diff (Value Bet - Actual)"] = -5.3395
comparison_RMSE.loc[6, "Mean Away Payout Diff (Value Bet - Actual)"] = -3.6312
comparison_RMSE.loc[6, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -0.5471
comparison_RMSE.loc[6, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 2.9411
comparison_RMSE.loc[6, "Home Value Bet ROI (%)"] = -91.01
comparison_RMSE.loc[6, "Away Value Bet ROI (%)"] = -91.80
comparison_RMSE.loc[6, "Home Non Value Bet ROI (%)"] = -104.71
comparison_RMSE.loc[6, "Away Non Value Bet ROI (%)"] = -107.50
comparison_RMSE.loc[6, "Home Actual ROI (%)"] = -98.68
comparison_RMSE.loc[6, "Away Actual ROI (%)"] = -97.96
comparison_RMSE.loc[6, "Per Home Value Bets, the Average Home Adjusted Payout"] = 2.0697
comparison_RMSE.loc[6, "Per Away Value Bets, the Average Away Adjusted Payout"] = 2.4442
comparison_RMSE.loc[6, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -0.7001
comparison_RMSE.loc[6, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -1.2868
comparison_RMSE.loc[6, "Theoretical Average EV for Home Value Bets"] = 5.1769
comparison_RMSE.loc[6, "Theoretical Average EV for All Home Bets"] = 1.3409
comparison_RMSE.loc[6, "Theoretical Average EV for Home Non-Value Bets"] = -1.6692
comparison_RMSE.loc[6, "Theoretical Average EV for Away Value Bets"] = 4.4044
comparison_RMSE.loc[6, "Theoretical Average EV for All Away Bets"] = 1.9161
comparison_RMSE.loc[6, "Theoretical Average EV for Away Non-Value Bets"] = -1.9346
comparison_RMSE.loc[6, "Home Accuracy (Threshold 0.5)"] = 0.6065
comparison_RMSE.loc[6, "Away Accuracy (Threshold 0.5)"] = 0.6065
comparison_RMSE.loc[6, "Home Brier Score"] = 0.2168
comparison_RMSE.loc[6, "Away Brier Score"] = 0.2168
comparison_RMSE.loc[6, "Home F1 Score"] = 0.7302
comparison_RMSE.loc[6, "Away F1 Score"] = 0.2738

comparison_RMSE.loc[7, "Proportion of Home Value Bets Overall"] = 0.2841
comparison_RMSE.loc[7, "Proportion of Away Value Bets Overall"] = 0.5426
comparison_RMSE.loc[7, "Mean Correct Home Value Bet"] = 0.1043
comparison_RMSE.loc[7, "Mean Correct Away Value Bet"] = 0.1693
comparison_RMSE.loc[7, "Mean Home Payout Diff (Value Bet - Actual)"] = -6.9231
comparison_RMSE.loc[7, "Mean Away Payout Diff (Value Bet - Actual)"] = -4.2262
comparison_RMSE.loc[7, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -3.9523
comparison_RMSE.loc[7, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 1.2632
comparison_RMSE.loc[7, "Home Value Bet ROI (%)"] = -95.44
comparison_RMSE.loc[7, "Away Value Bet ROI (%)"] = -98.83
comparison_RMSE.loc[7, "Home Non Value Bet ROI (%)"] = -103.29
comparison_RMSE.loc[7, "Away Non Value Bet ROI (%)"] = -107.60
comparison_RMSE.loc[7, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[7, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[7, "Per Home Value Bets, the Average Home Adjusted Payout"] = 1.2416
comparison_RMSE.loc[7, "Per Away Value Bets, the Average Away Adjusted Payout"] = 0.3744
comparison_RMSE.loc[7, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -0.5024
comparison_RMSE.loc[7, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -1.3503
comparison_RMSE.loc[7, "Theoretical Average EV for Home Value Bets"] = 5.3719
comparison_RMSE.loc[7, "Theoretical Average EV for All Home Bets"] = 0.2181
comparison_RMSE.loc[7, "Theoretical Average EV for Home Non-Value Bets"] = -1.8274
comparison_RMSE.loc[7, "Theoretical Average EV for Away Value Bets"] = 4.4145
comparison_RMSE.loc[7, "Theoretical Average EV for All Away Bets"] = 1.5935
comparison_RMSE.loc[7, "Theoretical Average EV for Away Non-Value Bets"] = -1.7529
comparison_RMSE.loc[7, "Home Accuracy (Threshold 0.5)"] = 0.5876
comparison_RMSE.loc[7, "Away Accuracy (Threshold 0.5)"] = 0.5876
comparison_RMSE.loc[7, "Home Brier Score"] = 0.2363
comparison_RMSE.loc[7, "Away Brier Score"] = 0.2363
comparison_RMSE.loc[7, "Home F1 Score"] = 0.7082
comparison_RMSE.loc[7, "Away F1 Score"] = 0.2973

# NCF Continuous w/ Dual Loss
comparison_RMSE.loc[8, "Proportion of Home Value Bets Overall"] = 0.3594
comparison_RMSE.loc[8, "Proportion of Away Value Bets Overall"] = 0.5843
comparison_RMSE.loc[8, "Mean Correct Home Value Bet"] = 0.1315
comparison_RMSE.loc[8, "Mean Correct Away Value Bet"] = 0.1730
comparison_RMSE.loc[8, "Mean Home Payout Diff (Value Bet - Actual)"] = -6.3361
comparison_RMSE.loc[8, "Mean Away Payout Diff (Value Bet - Actual)"] = -4.1692
comparison_RMSE.loc[8, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -2.5405
comparison_RMSE.loc[8, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 1.8652
comparison_RMSE.loc[8, "Home Value Bet ROI (%)"] = -94.40
comparison_RMSE.loc[8, "Away Value Bet ROI (%)"] = -96.72
comparison_RMSE.loc[8, "Home Non Value Bet ROI (%)"] = -101.08
comparison_RMSE.loc[8, "Away Non Value Bet ROI (%)"] = -99.71
comparison_RMSE.loc[8, "Home Actual ROI (%)"] = -98.68
comparison_RMSE.loc[8, "Away Actual ROI (%)"] = -97.96
comparison_RMSE.loc[8, "Per Home Value Bets, the Average Home Adjusted Payout"] = 1.5302
comparison_RMSE.loc[8, "Per Away Value Bets, the Average Away Adjusted Payout"] = 1.1061
comparison_RMSE.loc[8, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -0.1591
comparison_RMSE.loc[8, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 0.0472
comparison_RMSE.loc[8, "Theoretical Average EV for Home Value Bets"] = 7.2575
comparison_RMSE.loc[8, "Theoretical Average EV for All Home Bets"] = 1.2507
comparison_RMSE.loc[8, "Theoretical Average EV for Home Non-Value Bets"] = -2.1200
comparison_RMSE.loc[8, "Theoretical Average EV for Away Value Bets"] = 10.6438
comparison_RMSE.loc[8, "Theoretical Average EV for All Away Bets"] = 5.4299
comparison_RMSE.loc[8, "Theoretical Average EV for Away Non-Value Bets"] = -1.8988
comparison_RMSE.loc[8, "Home Accuracy (Threshold 0.5)"] = 0.5422
comparison_RMSE.loc[8, "Away Accuracy (Threshold 0.5)"] = 0.5422
comparison_RMSE.loc[8, "Home Brier Score"] = 0.2423
comparison_RMSE.loc[8, "Away Brier Score"] = 0.2423
comparison_RMSE.loc[8, "Home F1 Score"] = 0.6298
comparison_RMSE.loc[8, "Away F1 Score"] = 0.4003

comparison_RMSE.loc[9, "Proportion of Home Value Bets Overall"] = 0.3062
comparison_RMSE.loc[9, "Proportion of Away Value Bets Overall"] = 0.4833
comparison_RMSE.loc[9, "Mean Correct Home Value Bets"] = 0.0988
comparison_RMSE.loc[9, "Mean Correct Away Value Bets"] = 0.1591
comparison_RMSE.loc[9, "Mean Home Payout Diff (Value Bet - Actual)"] = -7.1069
comparison_RMSE.loc[9, "Mean Away Payout Diff (Value Bet - Actual)"] = -4.3953
comparison_RMSE.loc[9, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -4.3199
comparison_RMSE.loc[9, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 0.9249
comparison_RMSE.loc[9, "Home Value Bet ROI (%)"] = -108.97
comparison_RMSE.loc[9, "Away Value Bet ROI (%)"] = -89.93
comparison_RMSE.loc[9, "Home Non Value Bet ROI (%)"] = -97.57
comparison_RMSE.loc[9, "Away Non Value Bet ROI (%)"] = -114.93
comparison_RMSE.loc[9, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[9, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[9, "Per Home Value Bets, the Average Home Adjusted Payout"] = -2.7798
comparison_RMSE.loc[9, "Per Away Value Bets, the Average Away Adjusted Payout"] = 3.0608
comparison_RMSE.loc[9, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 0.3553
comparison_RMSE.loc[9, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -2.8799
comparison_RMSE.loc[9, "Theoretical Average EV for Home Value Bets"] = 5.5595
comparison_RMSE.loc[9, "Theoretical Average EV for All Home Bets"] = 0.4695
comparison_RMSE.loc[9, "Theoretical Average EV for Home Non-Value Bets"] = -1.7766
comparison_RMSE.loc[9, "Theoretical Average EV for Away Value Bets"] = 6.2991
comparison_RMSE.loc[9, "Theoretical Average EV for All Away Bets"] = 2.0896
comparison_RMSE.loc[9, "Theoretical Average EV for Away Non-Value Bets"] = -1.8485
comparison_RMSE.loc[9, "Home Accuracy (Threshold 0.5)"] = 0.4717
comparison_RMSE.loc[9, "Away Accuracy (Threshold 0.5)"] = 0.4717
comparison_RMSE.loc[9, "Home Brier Score"] = 0.2489
comparison_RMSE.loc[9, "Away Brier Score"] = 0.2489
comparison_RMSE.loc[9, "Home F1 Score"] = 0.6151
comparison_RMSE.loc[9, "Away F1 Score"] = 0.1576

# NCF Sport Layer Binary
comparison_RMSE.loc[10, "Proportion of Home Value Bets Overall"] = 0.5595
comparison_RMSE.loc[10, "Proportion of Away Value Bets Overall"] = 0.4298
comparison_RMSE.loc[10, "Mean Correct Home Value Bet"] = 0.5586
comparison_RMSE.loc[10, "Mean Correct Away Value Bet"] = 0.4298
comparison_RMSE.loc[10, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.0941
comparison_RMSE.loc[10, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.0411
comparison_RMSE.loc[10, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.9435
comparison_RMSE.loc[10, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 10.1215
comparison_RMSE.loc[10, "Home Value Bet ROI (%)"] = -20.59
comparison_RMSE.loc[10, "Away Value Bet ROI (%)"] = 36.44
comparison_RMSE.loc[10, "Home Non Value Bet ROI (%)"] = -197.86
comparison_RMSE.loc[10, "Away Non Value Bet ROI (%)"] = -199.28
comparison_RMSE.loc[10, "Home Actual ROI (%)"] = -98.68
comparison_RMSE.loc[10, "Away Actual ROI (%)"] = -97.96
comparison_RMSE.loc[10, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.9541
comparison_RMSE.loc[10, "Per Away Value Bets, the Average Away Adjusted Payout"] = 13.6438
comparison_RMSE.loc[10, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -473.2489
comparison_RMSE.loc[10, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -2259.6698
comparison_RMSE.loc[10, "Theoretical Average EV for Home Value Bets"] = 7.9571
comparison_RMSE.loc[10, "Theoretical Average EV for All Home Bets"] = 0.1811
comparison_RMSE.loc[10, "Theoretical Average EV for Home Non-Value Bets"] = -9.6946
comparison_RMSE.loc[10, "Theoretical Average EV for Away Value Bets"] = 13.5758
comparison_RMSE.loc[10, "Theoretical Average EV for All Away Bets"] = 0.1567
comparison_RMSE.loc[10, "Theoretical Average EV for Away Non-Value Bets"] = -9.9590
comparison_RMSE.loc[10, "Home Accuracy (Threshold 0.5)"] = 0.9987
comparison_RMSE.loc[10, "Away Accuracy (Threshold 0.5)"] = 0.9987
comparison_RMSE.loc[10, "Home Brier Score"] = 0.0009
comparison_RMSE.loc[10, "Away Brier Score"] = 0.0009
comparison_RMSE.loc[10, "Home F1 Score"] = 0.9989
comparison_RMSE.loc[10, "Away F1 Score"] = 0.9985

comparison_RMSE.loc[11, "Proportion of Home Value Bets Overall"] = 0.5780
comparison_RMSE.loc[11, "Proportion of Away Value Bets Overall"] = 0.4181
comparison_RMSE.loc[11, "Mean Correct Home Value Bets"] = 0.5702
comparison_RMSE.loc[11, "Mean Correct Away Value Bets"] = 0.4175
comparison_RMSE.loc[11, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.0378
comparison_RMSE.loc[11, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.1793
comparison_RMSE.loc[11, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.8184
comparison_RMSE.loc[11, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 9.3570
comparison_RMSE.loc[11, "Home Value Bet ROI (%)"] = -29.49
comparison_RMSE.loc[11, "Away Value Bet ROI (%)"] = 28.09
comparison_RMSE.loc[11, "Home Non Value Bet ROI (%)"] = -199.11
comparison_RMSE.loc[11, "Away Non Value Bet ROI (%)"] = -196.92
comparison_RMSE.loc[11, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[11, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[11, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.1482
comparison_RMSE.loc[11, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.8280
comparison_RMSE.loc[11, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -1411.2180
comparison_RMSE.loc[11, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -600.4369
comparison_RMSE.loc[11, "Theoretical Average EV for Home Value Bets"] = 7.2180
comparison_RMSE.loc[11, "Theoretical Average EV for All Home Bets"] = 0.0490
comparison_RMSE.loc[11, "Theoretical Average EV for Home Non-Value Bets"] = -9.7721
comparison_RMSE.loc[11, "Theoretical Average EV for Away Value Bets"] = 12.7158
comparison_RMSE.loc[11, "Theoretical Average EV for All Away Bets"] = -0.4317
comparison_RMSE.loc[11, "Theoretical Average EV for Away Non-Value Bets"] = -9.8781
comparison_RMSE.loc[11, "Home Accuracy (Threshold 0.5)"] = 0.9908
comparison_RMSE.loc[11, "Away Accuracy (Threshold 0.5)"] = 0.9908
comparison_RMSE.loc[11, "Home Brier Score"] = 0.0047
comparison_RMSE.loc[11, "Away Brier Score"] = 0.0047
comparison_RMSE.loc[11, "Home F1 Score"] = 0.9920
comparison_RMSE.loc[11, "Away F1 Score"] = 0.9891

# NCF with Specific Layer Continuous
comparison_RMSE.loc[12, "Proportion of Home Value Bets Overall"] = 0.4872
comparison_RMSE.loc[12, "Proportion of Away Value Bets Overall"] = 0.2879
comparison_RMSE.loc[12, "Mean Correct Home Value Bet"] = 0.2084
comparison_RMSE.loc[12, "Mean Correct Away Value Bet"] = 0.0683
comparison_RMSE.loc[12, "Mean Home Payout Diff (Value Bet - Actual)"] = -5.3161
comparison_RMSE.loc[12, "Mean Away Payout Diff (Value Bet - Actual)"] = -7.2631
comparison_RMSE.loc[12, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -0.5004
comparison_RMSE.loc[12, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -4.3227
comparison_RMSE.loc[12, "Home Value Bet ROI (%)"] = -101.16
comparison_RMSE.loc[12, "Away Value Bet ROI (%)"] = -97.88
comparison_RMSE.loc[12, "Home Non Value Bet ROI (%)"] = -96.33
comparison_RMSE.loc[12, "Away Non Value Bet ROI (%)"] = -98.00
comparison_RMSE.loc[12, "Home Actual ROI (%)"] = -98.68
comparison_RMSE.loc[12, "Away Actual ROI (%)"] = -97.96
comparison_RMSE.loc[12, "Per Home Value Bets, the Average Home Adjusted Payout"] = -0.2706
comparison_RMSE.loc[12, "Per Away Value Bets, the Average Away Adjusted Payout"] = 0.8938
comparison_RMSE.loc[12, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 0.5237
comparison_RMSE.loc[12, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 0.3915
comparison_RMSE.loc[12, "Theoretical Average EV for Home Value Bets"] = 4.6715
comparison_RMSE.loc[12, "Theoretical Average EV for All Home Bets"] = 1.9521
comparison_RMSE.loc[12, "Theoretical Average EV for Home Non-Value Bets"] = -0.6317
comparison_RMSE.loc[12, "Theoretical Average EV for Away Value Bets"] = 5.3676
comparison_RMSE.loc[12, "Theoretical Average EV for All Away Bets"] = 0.3328
comparison_RMSE.loc[12, "Theoretical Average EV for Away Non-Value Bets"] = -1.7031
comparison_RMSE.loc[12, "Home Accuracy (Threshold 0.5)"] = 0.5942
comparison_RMSE.loc[12, "Away Accuracy (Threshold 0.5)"] = 0.6040
comparison_RMSE.loc[12, "Home Brier Score"] = 0.2242
comparison_RMSE.loc[12, "Away Brier Score"] = 0.2187
comparison_RMSE.loc[12, "Home F1 Score"] = 0.7212
comparison_RMSE.loc[12, "Away F1 Score"] = 0.1968

comparison_RMSE.loc[13, "Proportion of Home Value Bets Overall"] = 0.5113
comparison_RMSE.loc[13, "Proportion of Away Value Bets Overall"] = 0.3279
comparison_RMSE.loc[13, "Mean Correct Home Value Bets"] = 0.2256
comparison_RMSE.loc[13, "Mean Correct Away Value Bets"] = 0.0838
comparison_RMSE.loc[13, "Mean Home Payout Diff (Value Bet - Actual)"] = -4.7044
comparison_RMSE.loc[13, "Mean Away Payout Diff (Value Bet - Actual)"] = -6.2667
comparison_RMSE.loc[13, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 0.4852
comparison_RMSE.loc[13, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -2.8178
comparison_RMSE.loc[13, "Home Value Bet ROI (%)"] = -98.51
comparison_RMSE.loc[13, "Away Value Bet ROI (%)"] = -94.80
comparison_RMSE.loc[13, "Home Non Value Bet ROI (%)"] = -103.73
comparison_RMSE.loc[13, "Away Non Value Bet ROI (%)"] = -106.77
comparison_RMSE.loc[13, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[13, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[13, "Per Home Value Bets, the Average Home Adjusted Payout"] = 0.3371
comparison_RMSE.loc[13, "Per Away Value Bets, the Average Away Adjusted Payout"] = 2.0325
comparison_RMSE.loc[13, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -0.5241
comparison_RMSE.loc[13, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -1.3256
comparison_RMSE.loc[13, "Theoretical Average EV for Home Value Bets"] = 4.2102
comparison_RMSE.loc[13, "Theoretical Average EV for All Home Bets"] = 1.7143
comparison_RMSE.loc[13, "Theoretical Average EV for Home Non-Value Bets"] = -0.8976
comparison_RMSE.loc[13, "Theoretical Average EV for Away Value Bets"] = 4.4301
comparison_RMSE.loc[13, "Theoretical Average EV for All Away Bets"] = 0.2073
comparison_RMSE.loc[13, "Theoretical Average EV for Away Non-Value Bets"] = -1.8524
comparison_RMSE.loc[13, "Home Accuracy (Threshold 0.5)"] = 0.5774
comparison_RMSE.loc[13, "Away Accuracy (Threshold 0.5)"] = 0.5858
comparison_RMSE.loc[13, "Home Brier Score"] = 0.2322
comparison_RMSE.loc[13, "Away Brier Score"] = 0.2299
comparison_RMSE.loc[13, "Home F1 Score"] = 0.7306
comparison_RMSE.loc[13, "Away F1 Score"] = 0.0761

# RF Binary
comparison_RMSE.loc[14, "Proportion of Home Value Bets Overall"] = 0.5670
comparison_RMSE.loc[14, "Proportion of Away Value Bets Overall"] = 0.4234
comparison_RMSE.loc[14, "Mean Correct Home Value Bet"] = 0.4979
comparison_RMSE.loc[14, "Mean Correct Away Value Bet"] = 0.3625
comparison_RMSE.loc[14, "Mean Home Payout Diff (Value Bet - Actual)"] = -1.8933
comparison_RMSE.loc[14, "Mean Away Payout Diff (Value Bet - Actual)"] = -1.7731
comparison_RMSE.loc[14, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 6.3453
comparison_RMSE.loc[14, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 6.6575
comparison_RMSE.loc[14, "Home Value Bet ROI (%)"] = -54.70
comparison_RMSE.loc[14, "Away Value Bet ROI (%)"] = -0.87
comparison_RMSE.loc[14, "Home Non Value Bet ROI (%)"] = -156.28
comparison_RMSE.loc[14, "Away Non Value Bet ROI (%)"] = -169.25
comparison_RMSE.loc[14, "Home Actual ROI (%)"] = -98.68
comparison_RMSE.loc[14, "Away Actual ROI (%)"] = -97.96
comparison_RMSE.loc[14, "Per Home Value Bets, the Average Home Adjusted Payout"] = 5.1587
comparison_RMSE.loc[14, "Per Away Value Bets, the Average Away Adjusted Payout"] = 11.5781
comparison_RMSE.loc[14, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -34.9294
comparison_RMSE.loc[14, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -57.1778
comparison_RMSE.loc[14, "Theoretical Average EV for Home Value Bets"] = 7.6538
comparison_RMSE.loc[14, "Theoretical Average EV for All Home Bets"] = 0.1005
comparison_RMSE.loc[14, "Theoretical Average EV for Home Non-Value Bets"] = -9.7899
comparison_RMSE.loc[14, "Theoretical Average EV for Away Value Bets"] = 12.9445
comparison_RMSE.loc[14, "Theoretical Average EV for All Away Bets"] = -0.2775
comparison_RMSE.loc[14, "Theoretical Average EV for Away Non-Value Bets"] = -9.9851
comparison_RMSE.loc[14, "Home Accuracy (Threshold 0.5)"] = 0.8700
comparison_RMSE.loc[14, "Away Accuracy (Threshold 0.5)"] = 0.8700
comparison_RMSE.loc[14, "Home Brier Score"] = 0.1300
comparison_RMSE.loc[14, "Away Brier Score"] = 0.1300
comparison_RMSE.loc[14, "Home F1 Score"] = 0.8863
comparison_RMSE.loc[14, "Away F1 Score"] = 0.8482

comparison_RMSE.loc[15, "Proportion of Home Value Bets Overall"] = 0.5840
comparison_RMSE.loc[15, "Proportion of Away Value Bets Overall"] = 0.4138
comparison_RMSE.loc[15, "Mean Correct Home Value Bet"] = 0.5149
comparison_RMSE.loc[15, "Mean Correct Away Value Bet"] = 0.3578
comparison_RMSE.loc[15, "Mean Home Payout Diff (Value Bet - Actual)"] = -1.3490
comparison_RMSE.loc[15, "Mean Away Payout Diff (Value Bet - Actual)"] = -1.3692
comparison_RMSE.loc[15, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 7.1958
comparison_RMSE.loc[15, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 6.9772
comparison_RMSE.loc[15, "Home Value Bet ROI (%)"] = -53.68
comparison_RMSE.loc[15, "Away Value Bet ROI (%)"] = 1.68
comparison_RMSE.loc[15, "Home Non Value Bet ROI (%)"] = -167.57
comparison_RMSE.loc[15, "Away Non Value Bet ROI (%)"] = -176.64
comparison_RMSE.loc[15, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[15, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[15, "Per Home Value Bets, the Average Home Adjusted Payout"] = 5.2534
comparison_RMSE.loc[15, "Per Away Value Bets, the Average Away Adjusted Payout"] = 11.7599
comparison_RMSE.loc[15, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -48.3007
comparison_RMSE.loc[15, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -65.0613
comparison_RMSE.loc[15, "Theoretical Average EV for Home Value Bets"] = 7.5024
comparison_RMSE.loc[15, "Theoretical Average EV for All Home Bets"] =  0.2437
comparison_RMSE.loc[15, "Theoretical Average EV for Home Non-Value Bets"] = -9.9453
comparison_RMSE.loc[15, "Theoretical Average EV for Away Value Bets"] = 12.7874
comparison_RMSE.loc[15, "Theoretical Average EV for All Away Bets"] = -0.5696
comparison_RMSE.loc[15, "Theoretical Average EV for Away Non-Value Bets"] = -10.0000
comparison_RMSE.loc[15, "Home Accuracy (Threshold 0.5)"] = 0.8749
comparison_RMSE.loc[15, "Away Accuracy (Threshold 0.5)"] = 0.8749
comparison_RMSE.loc[15, "Home Brier Score"] = 0.1251
comparison_RMSE.loc[15, "Away Brier Score"] = 0.1251
comparison_RMSE.loc[15, "Home F1 Score"] = 0.8921
comparison_RMSE.loc[15, "Away F1 Score"] = 0.8512

# RF Continuous 
comparison_RMSE.loc[16, "Proportion of Home Value Bets Overall"] = 0.2576
comparison_RMSE.loc[16, "Proportion of Away Value Bets Overall"] = 0.2834
comparison_RMSE.loc[16, "Mean Correct Home Value Bet"] = 0.1427
comparison_RMSE.loc[16, "Mean Correct Away Value Bet"] = 0.1123
comparison_RMSE.loc[16, "Mean Home Payout Diff (Value Bet - Actual)"] = -6.9769
comparison_RMSE.loc[16, "Mean Away Payout Diff (Value Bet - Actual)"] = -6.8522
comparison_RMSE.loc[16, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -3.8220
comparison_RMSE.loc[16, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -3.5007
comparison_RMSE.loc[16, "Home Value Bet ROI (%)"] = -77.55
comparison_RMSE.loc[16, "Away Value Bet ROI (%)"] = -81.73
comparison_RMSE.loc[16, "Home Non Value Bet ROI (%)"] = -106.02
comparison_RMSE.loc[16, "Away Non Value Bet ROI (%)"] = -104.38
comparison_RMSE.loc[16, "Home Actual ROI (%)"] = -98.68
comparison_RMSE.loc[16, "Away Actual ROI (%)"] = -97.96
comparison_RMSE.loc[16, "Per Home Value Bets, the Average Home Adjusted Payout"] = 4.0530
comparison_RMSE.loc[16, "Per Away Value Bets, the Average Away Adjusted Payout"] = 4.6101
comparison_RMSE.loc[16, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -1.0510
comparison_RMSE.loc[16, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -0.9811
comparison_RMSE.loc[16, "Theoretical Average EV for Home Value Bets"] = None
comparison_RMSE.loc[16, "Theoretical Average EV for All Home Bets"] = None
comparison_RMSE.loc[16, "Theoretical Average EV for Home Non-Value Bets"] = -0.4517
comparison_RMSE.loc[16, "Theoretical Average EV for Away Value Bets"] = 2.3678
comparison_RMSE.loc[16, "Theoretical Average EV for All Away Bets"] = 0.3307
comparison_RMSE.loc[16, "Theoretical Average EV for Away Non-Value Bets"] = -0.4748
comparison_RMSE.loc[16, "Home Accuracy (Threshold 0.5)"] = 0.6828
comparison_RMSE.loc[16, "Away Accuracy (Threshold 0.5)"] = 0.6828
comparison_RMSE.loc[16, "Home Brier Score"] = 0.2016
comparison_RMSE.loc[16, "Away Brier Score"] = 0.2016
comparison_RMSE.loc[16, "Home F1 Score"] = 0.7381
comparison_RMSE.loc[16, "Away F1 Score"] = 0.5980

comparison_RMSE.loc[17, "Proportion of Home Value Bets Overall"] = 0.1243
comparison_RMSE.loc[17, "Proportion of Away Value Bets Overall"] = 0.1440
comparison_RMSE.loc[17, "Mean Correct Home Value Bet"] = 0.0678
comparison_RMSE.loc[17, "Mean Correct Away Value Bet"] = 0.0614
comparison_RMSE.loc[17, "Mean Home Payout Diff (Value Bet - Actual)"] = -8.6296
comparison_RMSE.loc[17, "Mean Away Payout Diff (Value Bet - Actual)"] = -8.3222
comparison_RMSE.loc[17, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -7.3653
comparison_RMSE.loc[17, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -6.9289
comparison_RMSE.loc[17, "Home Value Bet ROI (%)"] = -98.32
comparison_RMSE.loc[17, "Away Value Bet ROI (%)"] = -103.26
comparison_RMSE.loc[17, "Home Non Value Bet ROI (%)"] = -101.45
comparison_RMSE.loc[17, "Away Non Value Bet ROI (%)"] = -102.77
comparison_RMSE.loc[17, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[17, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[17, "Per Home Value Bets, the Average Home Adjusted Payout"] = 0.3075
comparison_RMSE.loc[17, "Per Away Value Bets, the Average Away Adjusted Payout"] = -0.7639
comparison_RMSE.loc[17, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -0.2512
comparison_RMSE.loc[17, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -0.6499
comparison_RMSE.loc[17, "Theoretical Average EV for Home Value Bets"] = 1.2597
comparison_RMSE.loc[17, "Theoretical Average EV for All Home Bets"] = -0.4270
comparison_RMSE.loc[17, "Theoretical Average EV for Home Non-Value Bets"] = -0.6665
comparison_RMSE.loc[17, "Theoreitcal Average EV for Away Value Bets"] = 1.1495
comparison_RMSE.loc[17, "Theoretical Average EV for All Away Bets"] = -0.5500
comparison_RMSE.loc[17, "Theoretical Average EV for Away Non-Value Bets"] = -0.8359
comparison_RMSE.loc[17, "Home Accuracy (Threshold 0.5)"] = 0.6526
comparison_RMSE.loc[17, "Away Accuracy (Threshold 0.5)"] = 0.6526
comparison_RMSE.loc[17, "Home Brier Score"] = 0.2231
comparison_RMSE.loc[17, "Away Brier Score"] = 0.2231
comparison_RMSE.loc[17, "Home F1 Score"] = 0.7159
comparison_RMSE.loc[17, "Away F1 Score"] = 0.5528

# Baseline 
comparison_RMSE.loc[18, "Proportion of Home Value Bets Overall"] = 0.2838
comparison_RMSE.loc[18, "Proportion of Away Value Bets Overall"] = 0.4744
comparison_RMSE.loc[18, "Mean Correct Home Value Bet"] = 0.0967
comparison_RMSE.loc[18, "Mean Correct Away Value Bet"] = 0.1259
comparison_RMSE.loc[18, "Mean Home Payout Diff (Value Bet - Actual)"] = -7.1103
comparison_RMSE.loc[18, "Mean Away Payout Diff (Value Bet - Actual)"] = -5.3384
comparison_RMSE.loc[18, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -4.0886
comparison_RMSE.loc[18, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -0.4748
comparison_RMSE.loc[18, "Home Value Bet ROI (%)"] = -93.53
comparison_RMSE.loc[18, "Away Value Bet ROI (%)"] = -97.47
comparison_RMSE.loc[18, "Home Non Value Bet ROI (%)"] = -100.72
comparison_RMSE.loc[18, "Away Non Value Bet ROI (%)"] = -98.44
comparison_RMSE.loc[18, "Home Actual ROI (%)"] = -98.68
comparison_RMSE.loc[18, "Away Actual ROI (%)"] = -97.98
comparison_RMSE.loc[18, "Per Home Value Bets, the Average Home Adjusted Payout"] = 1.8995
comparison_RMSE.loc[18, "Per Away Value Bets, the Average Away Adjusted Payout"] = 0.9513
comparison_RMSE.loc[18, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -0.1099
comparison_RMSE.loc[18, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 0.2685
comparison_RMSE.loc[18, "Theoretical Average EV for Home Value Bets"] = 7.7117
comparison_RMSE.loc[18, "Theoretical Average EV for All Home Bets"] = 0.1504
comparison_RMSE.loc[18, "Theoretical Average EV for Home Non-Value Bets"] = -2.8458
comparison_RMSE.loc[18, "Theoretical Average EV for Away Value Bets"] = 11.1423
comparison_RMSE.loc[18, "Theoretical Average EV for All Away Bets"] = 3.8540
comparison_RMSE.loc[18, "Theoretical Average EV for Away Non-Value Bets"] = -2.7239
comparison_RMSE.loc[18, "Home Accuracy (Threshold 0.5)"] = 0.5129
comparison_RMSE.loc[18, "Away Accuracy (Threshold 0.5)"] = 0.5668
comparison_RMSE.loc[18, "Home Brier Score"] = 0.2526
comparison_RMSE.loc[18, "Away Brier Score"] = 0.2482
comparison_RMSE.loc[18, "Home F1 Score"] = 0.4160
comparison_RMSE.loc[18, "Away F1 Score"] = 0.1569

comparison_RMSE.loc[19, "Proportion of Home Value Bets Overall"] = 0.2239
comparison_RMSE.loc[19, "Proportion of Away Value Bets Overall"] = 0.4302
comparison_RMSE.loc[19, "Mean Correct Home Value Bet"] = 0.0798
comparison_RMSE.loc[19, "Mean Correct Away Value Bet"] = 0.1192
comparison_RMSE.loc[19, "Mean Home Payout Diff (Value Bet - Actual)"] = -7.4494
comparison_RMSE.loc[19, "Mean Away Payout Diff (Value Bet - Actual)"] = -5.3355
comparison_RMSE.loc[19, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -5.0048
comparison_RMSE.loc[19, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -0.9555
comparison_RMSE.loc[19, "Home Value Bet ROI (%)"] = -90.80
comparison_RMSE.loc[19, "Away Value Bet ROI (%)"] = -98.19
comparison_RMSE.loc[19, "Home Non Value Bet ROI (%)"] = -104.02
comparison_RMSE.loc[19, "Away Non Value Bet ROI (%)"] = -106.36
comparison_RMSE.loc[19, "Home Actual ROI (%)"] = -101.06
comparison_RMSE.loc[19, "Away Actual ROI (%)"] = -102.84
comparison_RMSE.loc[19, "Per Home Value Bets, the Average Home Adjusted Payout"] = 2.5808
comparison_RMSE.loc[19, "Per Away Value Bets, the Average Away Adjusted Payout"] = 0.6528
comparison_RMSE.loc[19, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -0.6324
comparison_RMSE.loc[19, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -1.1773
comparison_RMSE.loc[19, "Theoretical Average EV for Home Value Bets"] = 5.5755
comparison_RMSE.loc[19, "Theoretical Average EV for All Home Bets"] = -0.8384
comparison_RMSE.loc[19, "Theoretical Average EV for Home Non-Value Bets"] = -2.6884
comparison_RMSE.loc[19, "Theoretical Average EV for Away Value Bets"] = 6.5975
comparison_RMSE.loc[19, "Theoretical Average EV for All Away Bets"] = 1.4696
comparison_RMSE.loc[19, "Theoretical Average EV for Away Non-Value Bets"] = -2.4023
comparison_RMSE.loc[19, "Home Accuracy (Threshold 0.5)"] = 0.4963
comparison_RMSE.loc[19, "Away Accuracy (Threshold 0.5)"] = 0.5731
comparison_RMSE.loc[19, "Home Brier Score"] = 0.2540
comparison_RMSE.loc[19, "Away Brier Score"] = 0.2471
comparison_RMSE.loc[19, "Home F1 Score"] = 0.3322
comparison_RMSE.loc[19, "Away F1 Score"] = 0.0000

# Display the updated DataFrame
comparison_RMSE
# Out:
#                                            Model Type      Data Source  \
# 0                              Single Sport NN Binary       All sports
# 1                              Single Sport NN Binary  Basketball only
# 2                          Single Sport NN Continuous       All sports
# 3                          Single Sport NN Continuous  Basketball only
# 4                              Multi-Sport NCF Binary       All sports
# 5                              Multi-Sport NCF Binary  Basketball only
# 6                          Multi-Sport NCF Continuous       All sports
# 7                          Multi-Sport NCF Continuous  Basketball only
# 8                Multi-Sport NCF Continuous Dual loss       All sports
# 9                Multi-Sport NCF Continuous Dual loss  Basketball only
# 10    Multi-Sport NCF Binary w/ Sport Specific Layers       All sports
# 11    Multi-Sport NCF Binary w/ Sport Specific Layers  Basketball only
# ...

# %% [markdown]
# ## Model Comparison with EV as the DV

# %%
# Define the table data with all values cleared
data_EV = {
    "Model Type": [
        "Single-Sport (Bball)", 
        "Single-Sport (Bball)", 
        "Multi-Sport NCF w/ Sport Specific Layers", 
        "Multi-Sport NCF w/ Sport Specific Layers", 
        "Multi-Sport NCF", 
        "Multi-Sport NCF", 
        "Random Forest",
        "Random Forest",
    ],
    "Data Source": [
        "Basketball only", 
        "Basketball only", 
        "All sports", 
        "Basketball only", 
        "All sports", 
        "Basketball only", 
        "All sports",
        "Basketball only",
    ],
    "Proportion of Home Value Bets Overall": [""] * 8,
    "Proportion of Away Value Bets Overall": [""] * 8,
    "Mean Correct Home Value Bet": [""] * 8,
    "Mean Correct Away Value Bet": [""] * 8,
    "Mean Home Payout Diff (Value Bet - Actual)": [""] * 8,
    "Mean Away Payout Diff (Value Bet - Actual)": [""] * 8,
    "Mean Home VB Payout Diff (Value Bet - Non Value Bet)": [""] * 8,
    "Mean Away VB Payout Diff (Value Bet - Non Value Bet)": [""] * 8,
    "Home Value Bet ROI (%)": [""] * 8,
    "Away Value Bet ROI (%)": [""] * 8,
    "Home Non Value Bet ROI (%)": [""] * 8,
    "Away Non Value Bet ROI (%)": [""] * 8,
    "Home Actual ROI (%)": [""] * 8,
    "Away Actual ROI (%)": [""] * 8,
    "Per Home Value Bets, the Average Home Adjusted Payout": [""] * 8,
    "Per Away Value Bets, the Average Away Adjusted Payout": [""] * 8,
    "Per Home Non-Value Bets, the Average Home Adjusted Payout": [""] * 8,
    "Per Away Non-Value Bets, the Average Away Adjusted Payout": [""] * 8,
    "Theoretical Average EV for Home Value Bets": [""] * 8,
    "Theoretical Average EV for All Home Bets": [""] * 8,
    "Theoretical Average EV for Home Non-Value Bets": [""] * 8,
    "Theoretical Average EV for Away Value Bets": [""] * 8,
    "Theoretical Average EV for All Away Bets": [""] * 8,
    "Theoretical Average EV for Away Non-Value Bets": [""] * 8,
}

# Convert to DataFrame
comparison_EV = pd.DataFrame(data_EV)

# NN 
comparison_EV.loc[0, "Proportion of Home Value Bets Overall"] = 0.5549
comparison_EV.loc[0, "Proportion of Away Value Bets Overall"] = 0.4329
comparison_EV.loc[0, "Mean Correct Home Value Bet"] = 0.5549
comparison_EV.loc[0, "Mean Correct Away Value Bet"] = 0.4329
comparison_EV.loc[0, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.1317
comparison_EV.loc[0, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.0211
comparison_EV.loc[0, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.2105
comparison_EV.loc[0, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 9.7851
comparison_EV.loc[0, "Home Value Bet ROI (%)"] = -31.63
comparison_EV.loc[0, "Away Value Bet ROI (%)"] = 26.55
comparison_EV.loc[0, "Home Non Value Bet ROI (%)"] = -197.04
comparison_EV.loc[0, "Away Non Value Bet ROI (%)"] = -199.63
comparison_EV.loc[0, "Home Actual ROI (%)"] = -105.26
comparison_EV.loc[0, "Away Actual ROI (%)"] = -101.73
comparison_EV.loc[0, "Per Home Value Bets, the Average Home Adjusted Payout"] = 6.8369
comparison_EV.loc[0, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.6548
comparison_EV.loc[0, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -416.5639
comparison_EV.loc[0, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -2942.3612
comparison_EV.loc[0, "Theoretical Average EV for Home Value Bets"] = 3.3062
comparison_EV.loc[0, "Theoretical Average EV for All Home Bets"] = 1.8360
comparison_EV.loc[0, "Theoretical Average EV for Home Non-Value Bets"] = 0.0033
comparison_EV.loc[0, "Theoretical Average EV for Away Value Bets"] = 4.6959
comparison_EV.loc[0, "Theoretical Average EV for All Away Bets"] = 2.0334
comparison_EV.loc[0, "Theoretical Average EV for Away Non-Value Bets"] = 0.0013

comparison_EV.loc[1, "Proportion of Home Value Bets Overall"] = 0.5706
comparison_EV.loc[1, "Proportion of Away Value Bets Overall"] = 0.4282
comparison_EV.loc[1, "Mean Correct Home Value Bet"] = 0.5701
comparison_EV.loc[1, "Mean Correct Away Value Bet"] = 0.4268
comparison_EV.loc[1, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.0444
comparison_EV.loc[1, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.0006
comparison_EV.loc[1, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.8052
comparison_EV.loc[1, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 9.7144
comparison_EV.loc[1, "Home Value Bet ROI (%)"] = -27.39
comparison_EV.loc[1, "Away Value Bet ROI (%)"] = 26.87
comparison_EV.loc[1, "Home Non Value Bet ROI (%)"] = -198.97
comparison_EV.loc[1, "Away Non Value Bet ROI (%)"] = -199.99
comparison_EV.loc[1, "Home Actual ROI (%)"] = -101.06
comparison_EV.loc[1, "Away Actual ROI (%)"] = -102.84
comparison_EV.loc[1, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.2684
comparison_EV.loc[1, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.7289
comparison_EV.loc[1, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -1381.9352
comparison_EV.loc[1, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -102259.3002
comparison_EV.loc[1, "Theoretical Average EV for Home Value Bets"] = 3.4767
comparison_EV.loc[1, "Theoretical Average EV for All Home Bets"] = 1.9852
comparison_EV.loc[1, "Theoretical Average EV for Home Non-Value Bets"] = 0.0033
comparison_EV.loc[1, "Theoretical Average EV for Away Value Bets"] = 4.8183
comparison_EV.loc[1, "Theoretical Average EV for All Away Bets"] = 2.0636
comparison_EV.loc[1, "Theoretical Average EV for Away Non-Value Bets"] = 0.0007

# NCF with specific layers
comparison_EV.loc[2, "Proportion of Home Value Bets Overall"] = 0.5738
comparison_EV.loc[2, "Proportion of Away Value Bets Overall"] = 0.4401
comparison_EV.loc[2, "Mean Correct Home Value Bet"] = 0.5652
comparison_EV.loc[2, "Mean Correct Away Value Bet"] = 0.4310
comparison_EV.loc[2, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.0569
comparison_EV.loc[2, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.0247
comparison_EV.loc[2, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 10.0179
comparison_EV.loc[2, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 10.1542
comparison_EV.loc[2, "Home Value Bet ROI (%)"] = -24.43
comparison_EV.loc[2, "Away Value Bet ROI (%)"] = 31.26
comparison_EV.loc[2, "Home Non Value Bet ROI (%)"] = -198.66
comparison_EV.loc[2, "Away Non Value Bet ROI (%)"] = -199.56
comparison_EV.loc[2, "Home Actual ROI (%)"] = -98.68
comparison_EV.loc[2, "Away Actual ROI (%)"] = -97.96
comparison_EV.loc[2, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.6721
comparison_EV.loc[2, "Per Away Value Bets, the Average Away Adjusted Payout"] = 13.4038
comparison_EV.loc[2, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -1730.9393
comparison_EV.loc[2, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -4319.1073
comparison_EV.loc[2, "Theoretical Average EV for Home Value Bets"] = 3.2040
comparison_EV.loc[2, "Theoretical Average EV for All Home Bets"] = 1.8398
comparison_EV.loc[2, "Theoretical Average EV for Home Non-Value Bets"] = 0.0030
comparison_EV.loc[2, "Theoretical Average EV for Away Value Bets"] = 4.5448
comparison_EV.loc[2, "Theoretical Average EV for All Away Bets"] = 2.0025
comparison_EV.loc[2, "Theoretical Average EV for Away Non-Value Bets"] = 0.0038

comparison_EV.loc[3, "Proportion of Home Value Bets Overall"] = 0.5835
comparison_EV.loc[3, "Proportion of Away Value Bets Overall"] = 0.4388
comparison_EV.loc[3, "Mean Correct Home Value Bet"] = 0.5725
comparison_EV.loc[3, "Mean Correct Away Value Bet"] = 0.4268
comparison_EV.loc[3, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.0118
comparison_EV.loc[3, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.0011
comparison_EV.loc[3, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.8703
comparison_EV.loc[3, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 9.7134
comparison_EV.loc[3, "Home Value Bet ROI (%)"] = -30.63
comparison_EV.loc[3, "Away Value Bet ROI (%)"] = 21.40
comparison_EV.loc[3, "Home Non Value Bet ROI (%)"] = -199.72
comparison_EV.loc[3, "Away Non Value Bet ROI (%)"] = -199.98
comparison_EV.loc[3, "Home Actual ROI (%)"] = -101.06
comparison_EV.loc[3, "Away Actual ROI (%)"] = -102.84
comparison_EV.loc[3, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.0695
comparison_EV.loc[3, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.4802
comparison_EV.loc[3, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -6753.5530
comparison_EV.loc[3, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -100360.5660
comparison_EV.loc[3, "Theoretical Average EV for Home Value Bets"] = 3.1461
comparison_EV.loc[3, "Theoretical Average EV for All Home Bets"] = 1.8381
comparison_EV.loc[3, "Theoretical Average EV for Home Non-Value Bets"] = 0.0058
comparison_EV.loc[3, "Theoretical Average EV for Away Value Bets"] = 4.3856
comparison_EV.loc[3, "Theoretical Average EV for All Away Bets"] = 1.9268
comparison_EV.loc[3, "Theoretical Average EV for Away Non-Value Bets"] = 0.0045

# NCF 
comparison_EV.loc[4, "Proportion of Home Value Bets Overall"] = 0.7359
comparison_EV.loc[4, "Proportion of Away Value Bets Overall"] = 0.4416
comparison_EV.loc[4, "Mean Correct Home Value Bet"] = 0.5255
comparison_EV.loc[4, "Mean Correct Away Value Bet"] = 0.3412
comparison_EV.loc[4, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.9503
comparison_EV.loc[4, "Mean Away Payout Diff (Value Bet - Actual)"] = -1.5936
comparison_EV.loc[4, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 8.2311
comparison_EV.loc[4, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 7.0165
comparison_EV.loc[4, "Home Value Bet ROI (%)"] = -75.23
comparison_EV.loc[4, "Away Value Bet ROI (%)"] = -5.02
comparison_EV.loc[4, "Home Non Value Bet ROI (%)"] = -164.02
comparison_EV.loc[4, "Away Non Value Bet ROI (%)"] = -171.46
comparison_EV.loc[4, "Home Actual ROI (%)"] = -98.68
comparison_EV.loc[4, "Away Actual ROI (%)"] = -97.96
comparison_EV.loc[4, "Per Home Value Bets, the Average Home Adjusted Payout"] = 3.4683
comparison_EV.loc[4, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.2915
comparison_EV.loc[4, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -40.0562
comparison_EV.loc[4, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -43.8068
comparison_EV.loc[4, "Theoretical Average EV for Home Value Bets"] = 1.7602
comparison_EV.loc[4, "Theoretical Average EV for All Home Bets"] = 1.3094
comparison_EV.loc[4, "Theoretical Average EV for Home Non-Value Bets"] = 0.0534
comparison_EV.loc[4, "Theoretical Average EV for Away Value Bets"] = 1.2954
comparison_EV.loc[4, "Theoretical Average EV for All Away Bets"] = 0.5908
comparison_EV.loc[4, "Theoretical Average EV for Away Non-Value Bets"] = 0.0335

comparison_EV.loc[5, "Proportion of Home Value Bets Overall"] = 0.7070
comparison_EV.loc[5, "Proportion of Away Value Bets Overall"] = 0.3291
comparison_EV.loc[5, "Mean Correct Home Value Bet"] = 0.4884
comparison_EV.loc[5, "Mean Correct Away Value Bet"] = 0.2180
comparison_EV.loc[5, "Mean Home Payout Diff (Value Bet - Actual)"] = -2.2741
comparison_EV.loc[5, "Mean Away Payout Diff (Value Bet - Actual)"] = -3.2175
comparison_EV.loc[5, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 5.3457
comparison_EV.loc[5, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 3.2805
comparison_EV.loc[5, "Home Value Bet ROI (%)"] = -92.22
comparison_EV.loc[5, "Away Value Bet ROI (%)"] = -2.57
comparison_EV.loc[5, "Home Non Value Bet ROI (%)"] = -122.39
comparison_EV.loc[5, "Away Non Value Bet ROI (%)"] = -152.04
comparison_EV.loc[5, "Home Actual ROI (%)"] = -101.06
comparison_EV.loc[5, "Away Actual ROI (%)"] = -102.84
comparison_EV.loc[5, "Per Home Value Bets, the Average Home Adjusted Payout"] = 1.1262
comparison_EV.loc[5, "Per Away Value Bets, the Average Away Adjusted Payout"] = 14.7062
comparison_EV.loc[5, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -7.7409
comparison_EV.loc[5, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -16.7179
comparison_EV.loc[5, "Theoretical Average EV for Home Value Bets"] = 1.7010
comparison_EV.loc[5, "Theoretical Average EV for All Home Bets"] = 1.2069
comparison_EV.loc[5, "Theoretical Average EV for Home Non-Value Bets"] = 0.0148
comparison_EV.loc[5, "Theoretical Average EV for Away Value Bets"] = 2.1669
comparison_EV.loc[5, "Theoretical Average EV for All Away Bets"] = 0.7247
comparison_EV.loc[5, "Theoretical Average EV for Away Non-Value Bets"] = 0.0171

# Random Forest 
comparison_EV.loc[6, "Proportion of Home Value Bets Overall"] = 0.5518
comparison_EV.loc[6, "Proportion of Away Value Bets Overall"] = 0.4259
comparison_EV.loc[6, "Mean Correct Home Value Bet"] = 0.5511
comparison_EV.loc[6, "Mean Correct Away Value Bet"] = 0.4257
comparison_EV.loc[6, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.2369
comparison_EV.loc[6, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.1469
comparison_EV.loc[6, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.6579
comparison_EV.loc[6, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 9.9097
comparison_EV.loc[6, "Home Value Bet ROI (%)"] = -20.68
comparison_EV.loc[6, "Away Value Bet ROI (%)"] = 36.10
comparison_EV.loc[6, "Home Non Value Bet ROI (%)"] = -194.71
comparison_EV.loc[6, "Away Non Value Bet ROI (%)"] = -197.44
comparison_EV.loc[6, "Home Actual ROI (%)"] = -98.68
comparison_EV.loc[6, "Away Actual ROI (%)"] = -97.96
comparison_EV.loc[6, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.9426
comparison_EV.loc[6, "Per Away Value Bets, the Average Away Adjusted Payout"] = 13.6174
comparison_EV.loc[6, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -255.3377
comparison_EV.loc[6, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -846.9461
comparison_EV.loc[6, "Theoretical Average EV for Home Value Bets"] = 3.4689
comparison_EV.loc[6, "Theoretical Average EV for All Home Bets"] = -2.2680
comparison_EV.loc[6, "Theoretical Average EV for Home Non-Value Bets"] = -9.3312
comparison_EV.loc[6, "Theoretical Average EV for Away Value Bets"] = 4.6233
comparison_EV.loc[6, "Theoretical Average EV for All Away Bets"] = -3.6058
comparison_EV.loc[6, "Theoretical Average EV for Away Non-Value Bets"] = -9.7118

comparison_EV.loc[7, "Proportion of Home Value Bets Overall"] = 0.5595
comparison_EV.loc[7, "Proportion of Away Value Bets Overall"] = 0.4240
comparison_EV.loc[7, "Mean Correct Home Value Bet"] = 0.5588
comparison_EV.loc[7, "Mean Correct Away Value Bet"] = 0.4232
comparison_EV.loc[7, "Mean Home Payout Diff (Value Bet - Actual)"] = -0.2672
comparison_EV.loc[7, "Mean Away Payout Diff (Value Bet - Actual)"] = -0.0510
comparison_EV.loc[7, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 9.3596
comparison_EV.loc[7, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 9.6136
comparison_EV.loc[7, "Home Value Bet ROI (%)"] = -27.95
comparison_EV.loc[7, "Away Value Bet ROI (%)"] = 27.96
comparison_EV.loc[7, "Home Non Value Bet ROI (%)"] = -193.93
comparison_EV.loc[7, "Away Non Value Bet ROI (%)"] = -199.11
comparison_EV.loc[7, "Home Actual ROI (%)"] = -101.06
comparison_EV.loc[7, "Away Actual ROI (%)"] = -102.84
comparison_EV.loc[7, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.2147
comparison_EV.loc[7, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.8195
comparison_EV.loc[7, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = -287.9431
comparison_EV.loc[7, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = -1547.2377
comparison_EV.loc[7, "Theoretical Average EV for Home Value Bets"] = 3.3833
comparison_EV.loc[7, "Theoretical Average EV for All Home Bets"] = -2.2201
comparison_EV.loc[7, "Theoretical Average EV for Home Non-Value Bets"] = -9.3385
comparison_EV.loc[7, "Theoretical Average EV for Away Value Bets"] = 4.6685
comparison_EV.loc[7, "Theoretical Average EV for All Away Bets"] = -3.6820
comparison_EV.loc[7, "Theoretical Average EV for Away Non-Value Bets"] = -9.8279

# Display the updated DataFrame
comparison_EV
# Out:
#                                  Model Type      Data Source  \
# 0                      Single-Sport (Bball)  Basketball only
# 1                      Single-Sport (Bball)  Basketball only
# 2  Multi-Sport NCF w/ Sport Specific Layers       All sports
# 3  Multi-Sport NCF w/ Sport Specific Layers  Basketball only
# 4                           Multi-Sport NCF       All sports
# 5                           Multi-Sport NCF  Basketball only
# 6                             Random Forest       All sports
# 7                             Random Forest  Basketball only
#
#   Proportion of Home Value Bets Overall Proportion of Away Value Bets Overall  \
# 0                                0.5549                                0.4329
# 1                                0.5706                                0.4282
# 2                                0.5738                                0.4401
# 3                                0.5835                                0.4388
# ...

# %% [markdown]
# ## Model Comparison using MSE

# %%
# Clear results from the DataFrame
# Define the table data with all values cleared
data_MSE = {
    "Model Type": [
        "Multi-Sport NCF Model with specific Layers", 
        "Multi-Sport NCF Model with specific Layers", 
        "Multi-Sport NCF Model", 
        "Multi-Sport NCF Model", 
        "Single-Sport (Bball) Model", 
        "Single-Sport (Bball)", 
        "Single-Sport (Bball)",
        "Random Forest", 
        "Random Forest",
        "Baseline",
        "Baseline"
    ],
    "Data Used for Training": [
        "All sports (specific layers)", 
        "All sports (specific layers)", 
        "All sports", 
        "All sports", 
        "Basketball-only", 
        "Basketball-only", 
        "Basketball-only",
        "All sports",  
        "Basketball holdout only",
        "All sports",
        "Basketball holdout only",
        "All sports",
        "Basketball holdout only"
    ],
    "Data Used for Testing": [
        "All sports test data", 
        "Basketball-only holdout", 
        "All sports test data", 
        "Basketball-only holdout", 
        "Basketball test data", 
        "Basketball-only holdout", 
        "American Football only",
        "All sports test data",  
        "Basketball holdout only",
        "All sports test data",
        "Basketball holdout only"
    ],
    "Proportion of Home Value Bets Overall": [""] * 11,
    "Proportion of Away Value Bets Overall": [""] * 11,
    "Mean Correct Home Value Bet": [""] * 11,
    "Mean Correct Away Value Bet": [""] * 11,
    "Mean Home Payout Diff (Value Bet - Actual)": [""] * 11,
    "Mean Away Payout Diff (Value Bet - Actual)": [""] * 11,
    "Mean Home VB Payout Diff (Value Bet - Non Value Bet)": [""] * 11,
    "Mean Away VB Payout Diff (Value Bet - Non Value Bet)": [""] * 11,
    "Home Value Bet ROI (%)": [""] * 11,
    "Away Value Bet ROI (%)": [""] * 11,
    "Home Non Value Bet ROI (%)": [""] * 11,
    "Away Non Value Bet ROI (%)": [""] * 11,
    "Home Actual ROI (%)": [""] * 11,
    "Away Actual ROI (%)": [""] * 11,
    "Per Home Value Bets, the Average Home Adjusted Payout": [""] * 11,
    "Per Away Value Bets, the Average Away Adjusted Payout": [""] * 11,
    "Per Home Non-Value Bets, the Average Home Adjusted Payout": [""] * 11,
    "Per Away Non-Value Bets, the Average Away Adjusted Payout": [""] * 11,
    "Average EV for Home Value Bets": [""] * 11,
    "Average EV for All Home Bets": [""] * 11,
    "Average EV for Home Non-Value Bets": [""] * 11,
    "Average EV for Away Value Bets": [""] * 11,
    "Average EV for All Away Bets": [""] * 11,
    "Average EV for Away Non-Value Bets": [""] * 11,
    "Accuracy (Threshold 0.5)": [""] * 11,
    "Home Brier Score": [""] * 11,
    "Away Brier Score": [""] * 11,
    "F1 Score": [""] * 11
}

# Create the cleared DataFrame
comparison_MSE = pd.DataFrame(data_MSE)

comparison_MSE.loc[0, "Proportion of Home Value Bets Overall"] = 0.4532
comparison_MSE.loc[0, "Proportion of Away Value Bets Overall"] = 0.4787
comparison_MSE.loc[0, "Mean Correct Home Value Bet"] = 0.24229543039319873
comparison_MSE.loc[0, "Mean Correct Away Value Bet"] = 0.1860482769090633
comparison_MSE.loc[0, "Mean Home Payout Diff (Value Bet - Actual)"] = -6.058164403439562
comparison_MSE.loc[0, "Mean Away Payout Diff (Value Bet - Actual)"] = -6.119894151774861
comparison_MSE.loc[0, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -0.3489134188339652
comparison_MSE.loc[0, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 0.033123218619081775
comparison_MSE.loc[0, "Home Value Bet ROI (%)"] = -27.76
comparison_MSE.loc[0, "Away Value Bet ROI (%)"] = 20.39
comparison_MSE.loc[0, "Home Non Value Bet ROI (%)"] = -61.97
comparison_MSE.loc[0, "Away Non Value Bet ROI (%)"] = -33.34
comparison_MSE.loc[0, "Home Actual ROI (%)"] = -20.47
comparison_MSE.loc[0, "Away Actual ROI (%)"] = 37.63
comparison_MSE.loc[0, "Per Home Value Bets, the Average Home Adjusted Payout"] = 7.223727042214913
comparison_MSE.loc[0, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.039041781415749
comparison_MSE.loc[0, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 3.8032255992774218
comparison_MSE.loc[0, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 6.666042141289814
comparison_MSE.loc[0, "Average EV for Home Value Bets"] = 3.5747878204186967
comparison_MSE.loc[0, "Average EV for All Home Bets"] = 1.0500545190073807
comparison_MSE.loc[0, "Average EV for Home Non-Value Bets"] = -1.0428487911032627
comparison_MSE.loc[0, "Average EV for Away Value Bets"] = 4.218255351511809
comparison_MSE.loc[0, "Average EV for All Away Bets"] = 1.2919519044466616
comparison_MSE.loc[0, "Average EV for Away Non-Value Bets"] = -1.3957131371493605
comparison_MSE.loc[0, "Accuracy (Threshold 0.5)"] = 0.7232
comparison_MSE.loc[0, "Brier Score"] = 0.1874
comparison_MSE.loc[0, "F1 Score"] = 0.7862

comparison_MSE.loc[1, "Proportion of Home Value Bets Overall"] = 0.2735
comparison_MSE.loc[1, "Proportion of Away Value Bets Overall"] = 0.4200
comparison_MSE.loc[1, "Mean Correct Home Value Bet"] = 0.13625181706362519
comparison_MSE.loc[1, "Mean Correct Away Value Bet"] = 0.15229788661522978
comparison_MSE.loc[1, "Mean Home Payout Diff (Value Bet - Actual)"] = -7.230092775320442
comparison_MSE.loc[1, "Mean Away Payout Diff (Value Bet - Actual)"] = -6.147059006771839
comparison_MSE.loc[1, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -3.6859041397606354
comparison_MSE.loc[1, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -1.044266041821752
comparison_MSE.loc[1, "Home Value Bet ROI (%)"] = -4.49
comparison_MSE.loc[1, "Away Value Bet ROI (%)"] = 34.31
comparison_MSE.loc[1, "Home Non Value Bet ROI (%)"] = -54.66
comparison_MSE.loc[1, "Away Non Value Bet ROI (%)"] = -32.00
comparison_MSE.loc[1, "Home Actual ROI (%)"] = -27.37
comparison_MSE.loc[1, "Away Actual ROI (%)"] = 27.60
comparison_MSE.loc[1, "Per Home Value Bets, the Average Home Adjusted Payout"] = 9.550616152031186
comparison_MSE.loc[1, "Per Away Value Bets, the Average Away Adjusted Payout"] = 13.431227629405287
comparison_MSE.loc[1, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 4.534288892359176
comparison_MSE.loc[1, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 6.79991999412612
comparison_MSE.loc[1, "Average EV for Home Value Bets"] = 3.66077873500656
comparison_MSE.loc[1, "Average EV for All Home Bets"] = 0.15821306770464158
comparison_MSE.loc[1, "Average EV for Home Non-Value Bets"] = -1.1600669383572038
comparison_MSE.loc[1, "Average EV for Away Value Bets"] = 4.2011784140735555
comparison_MSE.loc[1, "Average EV for All Away Bets"] = 1.0656563859606805
comparison_MSE.loc[1, "Average EV for Away Non-Value Bets"] = -1.2053526757584005
comparison_MSE.loc[1, "Accuracy (Threshold 0.5)"] = 0.6905
comparison_MSE.loc[1, "Brier Score"] = 0.2060
comparison_MSE.loc[1, "F1 Score"] = 0.7554

comparison_MSE.loc[2, "Proportion of Home Value Bets Overall"] = 0.7366
comparison_MSE.loc[2, "Proportion of Away Value Bets Overall"] = 0.2310
comparison_MSE.loc[2, "Mean Correct Home Value Bet"] = 0.4461059662972522
comparison_MSE.loc[2, "Mean Correct Away Value Bet"] = 0.12942158797631698
comparison_MSE.loc[2, "Mean Home Payout Diff (Value Bet - Actual)"] = -3.9092115621332755
comparison_MSE.loc[2, "Mean Away Payout Diff (Value Bet - Actual)"] = -7.109849415533789
comparison_MSE.loc[2, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 4.833650911944805
comparison_MSE.loc[2, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -2.5741447416085443
comparison_MSE.loc[2, "Home Value Bet ROI (%)"] = -58.28
comparison_MSE.loc[2, "Away Value Bet ROI (%)"] = 40.33
comparison_MSE.loc[2, "Home Non Value Bet ROI (%)"] = -79.77
comparison_MSE.loc[2, "Away Non Value Bet ROI (%)"] = -10.94
comparison_MSE.loc[2, "Home Actual ROI (%)"] = -20.47
comparison_MSE.loc[2, "Away Actual ROI (%)"] = 37.63
comparison_MSE.loc[2, "Per Home Value Bets, the Average Home Adjusted Payout"] = 4.171931496724519
comparison_MSE.loc[2, "Per Away Value Bets, the Average Away Adjusted Payout"] = 14.032856030058651
comparison_MSE.loc[2, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 2.0232519461501233
comparison_MSE.loc[2, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 8.906287035477243
comparison_MSE.loc[2, "Average EV for Home Value Bets"] = 4.346425131936583
comparison_MSE.loc[2, "Average EV for All Home Bets"] = 3.0680410768618285
comparison_MSE.loc[2, "Average EV for Home Non-Value Bets"] = -0.5070133526613462
comparison_MSE.loc[2, "Average EV for Away Value Bets"] = 3.738170983948225
comparison_MSE.loc[2, "Average EV for All Away Bets"] = -1.8246877757323814
comparison_MSE.loc[2, "Average EV for Away Non-Value Bets"] = -3.4955770468515297
comparison_MSE.loc[2, "Accuracy (Threshold 0.5)"] = 0.6362
comparison_MSE.loc[2, "Brier Score"] = 0.1996
comparison_MSE.loc[2, "F1 Score"] = 0.7507

comparison_MSE.loc[3, "Proportion of Home Value Bets Overall"] = 0.6658
comparison_MSE.loc[3, "Proportion of Away Value Bets Overall"] = 0.0859
comparison_MSE.loc[3, "Mean Correct Home Value Bet"] = 0.4048417756904842
comparison_MSE.loc[3, "Mean Correct Away Value Bet"] = 0.06664430280666443
comparison_MSE.loc[3, "Mean Home Payout Diff (Value Bet - Actual)"] = -4.123643949805458
comparison_MSE.loc[3, "Mean Away Payout Diff (Value Bet - Actual)"] = -7.619532773916026
comparison_MSE.loc[3, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 3.666990669693032
comparison_MSE.loc[3, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -4.767624509827583
comparison_MSE.loc[3, "Home Value Bet ROI (%)"] = -57.47
comparison_MSE.loc[3, "Away Value Bet ROI (%)"] = 114.51
comparison_MSE.loc[3, "Home Non Value Bet ROI (%)"] = -75.02
comparison_MSE.loc[3, "Away Non Value Bet ROI (%)"] = -9.46
comparison_MSE.loc[3, "Home Actual ROI (%)"] = -27.37
comparison_MSE.loc[3, "Away Actual ROI (%)"] = 27.60
comparison_MSE.loc[3, "Per Home Value Bets, the Average Home Adjusted Payout"] = 4.253113779174147
comparison_MSE.loc[3, "Per Away Value Bets, the Average Away Adjusted Payout"] = 21.45134064335151
comparison_MSE.loc[3, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 2.498006822646946
comparison_MSE.loc[3, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 9.053815125060492
comparison_MSE.loc[3, "Average EV for Home Value Bets"] = 4.266937392181997
comparison_MSE.loc[3, "Average EV for All Home Bets"] = 2.7051115441594464
comparison_MSE.loc[3, "Average EV for Home Non-Value Bets"] = -0.40678138274377446
comparison_MSE.loc[3, "Average EV for Away Value Bets"] = 3.043882057083055
comparison_MSE.loc[3, "Average EV for All Away Bets"] = -2.6145228136658103
comparison_MSE.loc[3, "Average EV for Away Non-Value Bets"] = -3.1461013996884564
comparison_MSE.loc[3, "Accuracy (Threshold 0.5)"] = 0.6159
comparison_MSE.loc[3, "Brier Score"] = 0.2113
comparison_MSE.loc[3, "F1 Score"] = 0.7473

comparison_MSE.loc[4, "Proportion of Home Value Bets Overall"] = 0.2297
comparison_MSE.loc[4, "Proportion of Away Value Bets Overall"] = 0.2767
comparison_MSE.loc[4, "Mean Correct Home Value Bet"] = 0.16655997951606707
comparison_MSE.loc[4, "Mean Correct Away Value Bet"] = 0.18742798617334527
comparison_MSE.loc[4, "Mean Home Payout Diff (Value Bet - Actual)"] = -6.4098455526856934
comparison_MSE.loc[4, "Mean Away Payout Diff (Value Bet - Actual)"] = -5.285641369916029
comparison_MSE.loc[4, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -2.500254360254349
comparison_MSE.loc[4, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 0.5615741561966143
comparison_MSE.loc[4, "Home Value Bet ROI (%)"] = -9.85
comparison_MSE.loc[4, "Away Value Bet ROI (%)"] = 40.62
comparison_MSE.loc[4, "Home Non Value Bet ROI (%)"] = -59.51
comparison_MSE.loc[4, "Away Non Value Bet ROI (%)"] = -37.25
comparison_MSE.loc[4, "Home Actual ROI (%)"] = -31.97
comparison_MSE.loc[4, "Away Actual ROI (%)"] = 27.79
comparison_MSE.loc[4, "Per Home Value Bets, the Average Home Adjusted Payout"] = 9.015477126969639
comparison_MSE.loc[4, "Per Away Value Bets, the Average Away Adjusted Payout"] = 14.06236792392418
comparison_MSE.loc[4, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 4.0490709560644715
comparison_MSE.loc[4, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 6.274855065766461
comparison_MSE.loc[4, "Average EV for Home Value Bets"] = 1.9852119486398374
comparison_MSE.loc[4, "Average EV for All Home Bets"] = -0.11863778655350468
comparison_MSE.loc[4, "Average EV for Home Non-Value Bets"] = -0.7459115816236155
comparison_MSE.loc[4, "Average EV for Away Value Bets"] = 2.104534513887048
comparison_MSE.loc[4, "Average EV for All Away Bets"] = -0.14242349066736817
comparison_MSE.loc[4, "Average EV for Away Non-Value Bets"] = -1.0018352159491546
comparison_MSE.loc[4, "Accuracy (Threshold 0.5)"] = 0.6792
comparison_MSE.loc[4, "Brier Score"] = 0.1709
comparison_MSE.loc[4, "F1 Score"] = 0.7389

comparison_MSE.loc[5, "Proportion of Home Value Bets Overall"] = 0.2110
comparison_MSE.loc[5, "Proportion of Away Value Bets Overall"] = 0.2734
comparison_MSE.loc[5, "Mean Correct Home Value Bet"] = 0.172089902717209
comparison_MSE.loc[5, "Mean Correct Away Value Bet"] = 0.20837526557083752
comparison_MSE.loc[5, "Mean Home Payout Diff (Value Bet - Actual)"] = -6.645155348403694
comparison_MSE.loc[5, "Mean Away Payout Diff (Value Bet - Actual)"] = -5.012583805140241
comparison_MSE.loc[5, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -2.6967100186117614
comparison_MSE.loc[5, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 0.9550773183129914
comparison_MSE.loc[5, "Home Value Bet ROI (%)"] = -11.22
comparison_MSE.loc[5, "Away Value Bet ROI (%)"] = 25.70
comparison_MSE.loc[5, "Home Non Value Bet ROI (%)"] = -51.75
comparison_MSE.loc[5, "Away Non Value Bet ROI (%)"] = -28.47
comparison_MSE.loc[5, "Home Actual ROI (%)"] = -27.37
comparison_MSE.loc[5, "Away Actual ROI (%)"] = 27.60
comparison_MSE.loc[5, "Per Home Value Bets, the Average Home Adjusted Payout"] = 8.8781816012833
comparison_MSE.loc[5, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.56986601153743
comparison_MSE.loc[5, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 4.825093848021577
comparison_MSE.loc[5, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 7.153371342928891
comparison_MSE.loc[5, "Average EV for Home Value Bets"] = 1.8996535614993282
comparison_MSE.loc[5, "Average EV for All Home Bets"] = -0.24234134950707723
comparison_MSE.loc[5, "Average EV for Home Non-Value Bets"] = -0.8151792742617664
comparison_MSE.loc[5, "Average EV for Away Value Bets"] = 2.0176410773452065
comparison_MSE.loc[5, "Average EV for All Away Bets"] = -0.13428474787514058
comparison_MSE.loc[5, "Average EV for Away Non-Value Bets"] = -0.9439890634589738
comparison_MSE.loc[5, "Accuracy (Threshold 0.5)"] = 0.6584
comparison_MSE.loc[5, "Brier Score"] = 0.1818
comparison_MSE.loc[5, "F1 Score"] = 0.7242

comparison_MSE.loc[6, "Proportion of Home Value Bets Overall"] = 0.3257
comparison_MSE.loc[6, "Proportion of Away Value Bets Overall"] = 0.1214
comparison_MSE.loc[6, "Mean Correct Home Value Bet"] = 0.26878407205498933
comparison_MSE.loc[6, "Mean Correct Away Value Bet"] = 0.11803744963261437
comparison_MSE.loc[6, "Mean Home Payout Diff (Value Bet - Actual)"] = -5.479360268640274
comparison_MSE.loc[6, "Mean Away Payout Diff (Value Bet - Actual)"] = -5.902430696077257
comparison_MSE.loc[6, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -0.1076731781396684
comparison_MSE.loc[6, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -2.7631851770442184
comparison_MSE.loc[6, "Home Value Bet ROI (%)"] = -36.05
comparison_MSE.loc[6, "Away Value Bet ROI (%)"] = 26.85
comparison_MSE.loc[6, "Home Non Value Bet ROI (%)"] = -53.60
comparison_MSE.loc[6, "Away Non Value Bet ROI (%)"] = -21.50
comparison_MSE.loc[6, "Home Actual ROI (%)"] = -28.71
comparison_MSE.loc[6, "Away Actual ROI (%)"] = 2.91
comparison_MSE.loc[6, "Per Home Value Bets, the Average Home Adjusted Payout"] = 6.395274436452822
comparison_MSE.loc[6, "Per Away Value Bets, the Average Away Adjusted Payout"] = 12.684789941014056
comparison_MSE.loc[6, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 4.639903452321623
comparison_MSE.loc[6, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 7.8498471494425655
comparison_MSE.loc[6, "Average EV for Home Value Bets"] = 1.9299180873816786
comparison_MSE.loc[6, "Average EV for All Home Bets"] = 0.28520253418605074
comparison_MSE.loc[6, "Average EV for Home Non-Value Bets"] = -0.5091170335084282
comparison_MSE.loc[6, "Average EV for Away Value Bets"] = 1.5681430383878916
comparison_MSE.loc[6, "Average EV for All Away Bets"] = -1.1461677164045514
comparison_MSE.loc[6, "Average EV for Away Non-Value Bets"] = -1.5210603806758574
comparison_MSE.loc[6, "Accuracy (Threshold 0.5)"] = 0.6648
comparison_MSE.loc[6, "Brier Score"] = 0.1728
comparison_MSE.loc[6, "F1 Score"] = 0.7383

comparison_MSE.loc[7, "Proportion of Home Value Bets Overall"] = 0.4562
comparison_MSE.loc[7, "Proportion of Away Value Bets Overall"] = 0.4029
comparison_MSE.loc[7, "Mean Correct Home Value Bet"] = 0.4536
comparison_MSE.loc[7, "Mean Correct Away Value Bet"] = 0.3981
comparison_MSE.loc[7, "Mean Home Payout Diff (Value Bet - Actual)"] = -3.2544
comparison_MSE.loc[7, "Mean Away Payout Diff (Value Bet - Actual)"] = -3.4395
comparison_MSE.loc[7, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 5.5563
comparison_MSE.loc[7, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 6.3485
comparison_MSE.loc[7, "Home Value Bet ROI (%)"] = -48.38%
comparison_MSE.loc[7, "Away Value Bet ROI (%)"] = -30.08%
comparison_MSE.loc[7, "Home Non Value Bet ROI (%)"] = -84.22%
comparison_MSE.loc[7, "Away Non Value Bet ROI (%)"] = -78.59%
comparison_MSE.loc[7, "Home Actual ROI (%)"] = -21.52%
comparison_MSE.loc[7, "Away Actual ROI (%)"] = 36.02%
comparison_MSE.loc[7, "Per Home Value Bets, the Average Home Adjusted Payout"] = 5.1624
comparison_MSE.loc[7, "Per Away Value Bets, the Average Away Adjusted Payout"] = 6.9916
comparison_MSE.loc[7, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 1.5784
comparison_MSE.loc[7, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 2.1406
comparison_MSE.loc[7, "Average EV for Home Value Bets"] = 2.3708
comparison_MSE.loc[7, "Average EV for All Home Bets"] = 0.0816
comparison_MSE.loc[7, "Average EV for Home Non-Value Bets"] = -1.8386
comparison_MSE.loc[7, "Average EV for Away Value Bets"] = 3.6154
comparison_MSE.loc[7, "Average EV for All Away Bets"] = 0.1166
comparison_MSE.loc[7, "Average EV for Away Non-Value Bets"] = -2.2440
comparison_MSE.loc[7, "Accuracy (Threshold 0.5)"] = 0.8854
comparison_MSE.loc[7, "Home Brier Score"] = 0.1174
comparison_MSE.loc[7, "Away Brier Score"] = 0.1159
comparison_MSE.loc[7, "F1 Score"] = 0.9020

comparison_MSE.loc[8, "Proportion of Home Value Bets Overall"] = 0.4052
comparison_MSE.loc[8, "Proportion of Away Value Bets Overall"] = 0.3738
comparison_MSE.loc[8, "Mean Correct Home Value Bet"] = 0.4038
comparison_MSE.loc[8, "Mean Correct Away Value Bet"] = 0.3716
comparison_MSE.loc[8, "Mean Home Payout Diff (Value Bet - Actual)"] = -3.5514
comparison_MSE.loc[8, "Mean Away Payout Diff (Value Bet - Actual)"] = -3.1610
comparison_MSE.loc[8, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = 4.2591
comparison_MSE.loc[8, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = 5.8603
comparison_MSE.loc[8, "Home Value Bet ROI (%)"] = -42.92%
comparison_MSE.loc[8, "Away Value Bet ROI (%)"] = -23.60%
comparison_MSE.loc[8, "Home Non Value Bet ROI (%)"] = -76.98%
comparison_MSE.loc[8, "Away Non Value Bet ROI (%)"] = -74.42%
comparison_MSE.loc[8, "Home Actual ROI (%)"] = -27.37%
comparison_MSE.loc[8, "Away Actual ROI (%)"] = 27.60%
comparison_MSE.loc[8, "Per Home Value Bets, the Average Home Adjusted Payout"] = 5.7079
comparison_MSE.loc[8, "Per Away Value Bets, the Average Away Adjusted Payout"] = 7.6401
comparison_MSE.loc[8, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 2.3025
comparison_MSE.loc[8, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 2.5575
comparison_MSE.loc[8, "Average EV for Home Value Bets"] = 2.0048
comparison_MSE.loc[8, "Average EV for All Home Bets"] = -0.3048
comparison_MSE.loc[8, "Average EV for Home Non-Value Bets"] = -1.8784
comparison_MSE.loc[8, "Average EV for Away Value Bets"] = 3.1626
comparison_MSE.loc[8, "Average EV for All Away Bets"] = -0.3532
comparison_MSE.loc[8, "Average EV for Away Non-Value Bets"] = -2.4515
comparison_MSE.loc[8, "Accuracy (Threshold 0.5)"] = 0.8802
comparison_MSE.loc[8, "Home Brier Score"] = 0.1269
comparison_MSE.loc[8, "Away Brier Score"] = 0.1159
comparison_MSE.loc[8, "F1 Score"] = 0.8994

comparison_MSE.loc[9, "Proportion of Home Value Bets Overall"] = 0.2838
comparison_MSE.loc[9, "Proportion of Away Value Bets Overall"] = 0.4744
comparison_MSE.loc[9, "Mean Correct Home Value Bet"] = 0.0967
comparison_MSE.loc[9, "Mean Correct Away Value Bet"] = 0.1259
comparison_MSE.loc[9, "Mean Home Payout Diff (Value Bet - Actual)"] = -8.1317
comparison_MSE.loc[9, "Mean Away Payout Diff (Value Bet - Actual)"] = -7.2751
comparison_MSE.loc[9, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -5.1100
comparison_MSE.loc[9, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -2.4115
comparison_MSE.loc[9, "Home Value Bet ROI (%)"] = 6.85%
comparison_MSE.loc[9, "Away Value Bet ROI (%)"] = 32.44%
comparison_MSE.loc[9, "Home Non Value Bet ROI (%)"] = -49.05%
comparison_MSE.loc[9, "Away Non Value Bet ROI (%)"] = -25.73%
comparison_MSE.loc[9, "Home Actual ROI (%)"] = -21.54%
comparison_MSE.loc[9, "Away Actual ROI (%)"] = 36.02%
comparison_MSE.loc[9, "Per Home Value Bets, the Average Home Adjusted Payout"] = 10.6853
comparison_MSE.loc[9, "Per Away Value Bets, the Average Away Adjusted Payout"] = 13.2442
comparison_MSE.loc[9, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 5.0947
comparison_MSE.loc[9, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 7.4266
comparison_MSE.loc[9, "Average EV for Home Value Bets"] = 7.7117
comparison_MSE.loc[9, "Average EV for All Home Bets"] = 0.1504
comparison_MSE.loc[9, "Average EV for Home Non-Value Bets"] = -2.8458
comparison_MSE.loc[9, "Average EV for Away Value Bets"] = 11.1423
comparison_MSE.loc[9, "Average EV for All Away Bets"] = 3.8540
comparison_MSE.loc[9, "Average EV for Away Non-Value Bets"] = -2.7239
comparison_MSE.loc[9, "Accuracy (Threshold 0.5)"] = 0.5129
comparison_MSE.loc[9, "Home Brier Score"] = 0.2526
comparison_MSE.loc[9, "Away Brier Score"] = 0.2482
comparison_MSE.loc[9, "F1 Score"] = 0.4160

comparison_MSE.loc[10, "Proportion of Home Value Bets Overall"] = 0.2239
comparison_MSE.loc[10, "Proportion of Away Value Bets Overall"] = 0.4302
comparison_MSE.loc[10, "Mean Correct Home Value Bet"] = 0.0798
comparison_MSE.loc[10, "Mean Correct Away Value Bet"] = 0.1192
comparison_MSE.loc[10, "Mean Home Payout Diff (Value Bet - Actual)"] = -8.1864
comparison_MSE.loc[10, "Mean Away Payout Diff (Value Bet - Actual)"] = -6.8963
comparison_MSE.loc[10, "Mean Home VB Payout Diff (Value Bet - Non Value Bet)"] = -5.7419
comparison_MSE.loc[10, "Mean Away VB Payout Diff (Value Bet - Non Value Bet)"] = -2.5162
comparison_MSE.loc[10, "Home Value Bet ROI (%)"] = 14.02%
comparison_MSE.loc[10, "Away Value Bet ROI (%)"] = 36.52%
comparison_MSE.loc[10, "Home Non Value Bet ROI (%)"] = -49.00%
comparison_MSE.loc[10, "Away Non Value Bet ROI (%)"] = -26.58%
comparison_MSE.loc[10, "Home Actual ROI (%)"] = -27.37%
comparison_MSE.loc[10, "Away Actual ROI (%)"] = 27.60%
comparison_MSE.loc[10, "Per Home Value Bets, the Average Home Adjusted Payout"] = 11.4021
comparison_MSE.loc[10, "Per Away Value Bets, the Average Away Adjusted Payout"] = 13.6522
comparison_MSE.loc[10, "Per Home Non-Value Bets, the Average Home Adjusted Payout"] = 5.0997
comparison_MSE.loc[10, "Per Away Non-Value Bets, the Average Away Adjusted Payout"] = 7.3417
comparison_MSE.loc[10, "Average EV for Home Value Bets"] = 5.5755
comparison_MSE.loc[10, "Average EV for All Home Bets"] = -0.8384
comparison_MSE.loc[10, "Average EV for Home Non-Value Bets"] = -2.6884
comparison_MSE.loc[10, "Average EV for Away Value Bets"] = 6.5975
comparison_MSE.loc[10, "Average EV for All Away Bets"] = 1.4696
comparison_MSE.loc[10, "Average EV for Away Non-Value Bets"] = -2.4023
comparison_MSE.loc[10, "Accuracy (Threshold 0.5)"] = 0.4963
comparison_MSE.loc[10, "Home Brier Score"] = 0.2540
comparison_MSE.loc[10, "Away Brier Score"] = 0.2471
comparison_MSE.loc[10, "F1 Score"] = 0.3322

# Display the updated DataFrame
comparison_MSE

# %% [markdown]
# The positive EV suggests that in theory, home value bets have potential profitability across many bets due to high payouts on unlikely events. However, the realized ROI remains negative because the distribution is skewed towards rare, high-reward events. These events do not occur frequently enough in practice to cover the accumulated losses, especially in the timeframe you’re examining.
